# %%
# %matplotlib tk
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
import glob, os
import seaborn as sns
import matplotlib.ticker as plticker
warnings.simplefilter("ignore")
plt.rcParams['figure.figsize'] = [10, 5]
#plt.rcParams.update({'font.size': 14})

# %%
dfbp0_surface = pd.read_csv('ernwin-simrna-new_output/CopStemsErnwin900_expand_00.csv_bp',sep="\t")

dfbp1_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_1.csv_bp',sep="\t")

dfbp2_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_2.csv_bp',sep="\t")

dfbp3_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_3.csv_bp',sep="\t")

# %%
#Load al Files, sort them and put them into dataframes
df001_surface = pd.read_csv('ernwin-simrna-new_output/CopStemsErnwin900_expand_00_1.csv',sep="\t",skiprows=[i for i in range(1,3)])
df002_surface = pd.read_csv('ernwin-simrna-new_output/CopStemsErnwin900_expand_00_2.csv',sep="\t",skiprows=[i for i in range(1,3)])
df003_surface = pd.read_csv('ernwin-simrna-new_output/CopStemsErnwin900_expand_00_3.csv',sep="\t",skiprows=[i for i in range(1,3)])
df004_surface = pd.read_csv('ernwin-simrna-new_output/CopStemsErnwin900_expand_00_4.csv',sep="\t",skiprows=[i for i in range(1,3)])
df005_surface = pd.read_csv('ernwin-simrna-new_output/CopStemsErnwin900_expand_00_5.csv',sep="\t",skiprows=[i for i in range(1,3)])
df006_surface = pd.read_csv('ernwin-simrna-new_output/CopStemsErnwin900_expand_00_6.csv',sep="\t",skiprows=[i for i in range(1,3)])
df007_surface = pd.read_csv('ernwin-simrna-new_output/CopStemsErnwin900_expand_00_7.csv',sep="\t",skiprows=[i for i in range(1,3)])
df008_surface = pd.read_csv('ernwin-simrna-new_output/CopStemsErnwin900_expand_00_8.csv',sep="\t",skiprows=[i for i in range(1,3)])
df009_surface = pd.read_csv('ernwin-simrna-new_output/CopStemsErnwin900_expand_00_9.csv',sep="\t",skiprows=[i for i in range(1,3)])
df010_surface = pd.read_csv('ernwin-simrna-new_output/CopStemsErnwin900_expand_00_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames00_surface = [df001_surface,df002_surface,df003_surface,df004_surface,df005_surface,df006_surface,df007_surface,df008_surface,df009_surface,df010_surface]

df0_surface = pd.concat(frames00_surface)

dfint0_surface = pd.read_csv('ernwin-simrna-new_output/CopStemsErnwin900_expand_00.csv',sep="\t")
#dfint0_surface_best = pd.read_csv('SimRNA_output/CopStemsErnwin900_expand_00.interaction-csv',sep="\t")

# %%
df101_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_1_1.csv',sep="\t",skiprows=[i for i in range(1,3)])
df102_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_1_2.csv',sep="\t",skiprows=[i for i in range(1,3)])
df103_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_1_3.csv',sep="\t",skiprows=[i for i in range(1,3)])
df104_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_1_4.csv',sep="\t",skiprows=[i for i in range(1,3)])
df105_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_1_5.csv',sep="\t",skiprows=[i for i in range(1,3)])
df106_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_1_6.csv',sep="\t",skiprows=[i for i in range(1,3)])
df107_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_1_7.csv',sep="\t",skiprows=[i for i in range(1,3)])
df108_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_1_8.csv',sep="\t",skiprows=[i for i in range(1,3)])
df109_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_1_9.csv',sep="\t",skiprows=[i for i in range(1,3)])
df110_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_1_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames1_expand = [df101_expand,df102_expand,df103_expand,
          df104_expand,df105_expand,df106_expand,
          df107_expand,df108_expand,df109_expand,
          df110_expand]

df1_expand = pd.concat(frames1_expand)

dfint1_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_1.csv',sep="\t")
dfint1_expand_best = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_1.interaction-csv',sep="\t")

# %%
df201_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_2_1.csv',sep="\t",skiprows=[i for i in range(1,3)])
df202_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_2_2.csv',sep="\t",skiprows=[i for i in range(1,3)])
df203_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_2_3.csv',sep="\t",skiprows=[i for i in range(1,3)])
df204_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_2_4.csv',sep="\t",skiprows=[i for i in range(1,3)])
df205_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_2_5.csv',sep="\t",skiprows=[i for i in range(1,3)])
df206_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_2_6.csv',sep="\t",skiprows=[i for i in range(1,3)])
df207_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_2_7.csv',sep="\t",skiprows=[i for i in range(1,3)])
df208_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_2_8.csv',sep="\t",skiprows=[i for i in range(1,3)])
df209_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_2_9.csv',sep="\t",skiprows=[i for i in range(1,3)])
df210_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_2_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames2_expand = [df201_expand,df202_expand,df203_expand,
          df204_expand,df205_expand,df206_expand,
          df207_expand,df208_expand,df209_expand,
          df210_expand]

df2_expand = pd.concat(frames2_expand)

dfint2_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_2.csv',sep="\t")
dfint2_expand_best = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_2.interaction-csv',sep="\t")

# %%
df201_expand01 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long01_0_1.csv',sep="\t",skiprows=[i for i in range(1,3)])
df202_expand01 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long01_0_2.csv',sep="\t",skiprows=[i for i in range(1,3)])
df203_expand01 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long01_0_3.csv',sep="\t",skiprows=[i for i in range(1,3)])
df204_expand01 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long01_0_4.csv',sep="\t",skiprows=[i for i in range(1,3)])
df205_expand01 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long01_0_5.csv',sep="\t",skiprows=[i for i in range(1,3)])
df206_expand01 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long01_0_6.csv',sep="\t",skiprows=[i for i in range(1,3)])
df207_expand01 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long01_0_7.csv',sep="\t",skiprows=[i for i in range(1,3)])
df208_expand01 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long01_0_8.csv',sep="\t",skiprows=[i for i in range(1,3)])
df209_expand01 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long01_0_9.csv',sep="\t",skiprows=[i for i in range(1,3)])
df210_expand01 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long01_0_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames2_expand01 = [df201_expand01,df202_expand01,df203_expand01,
          df204_expand01,df205_expand01,df206_expand01,
          df207_expand01,df208_expand01,df209_expand01,
          df210_expand01]

df2_expand01 = pd.concat(frames2_expand01)

dfint2_expand01 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long01_0.csv',sep="\t")
#dfint2_expand01_best = pd.read_csv('ernwin-simrna-new_output/CopStems_expand01_2.interaction-csv',sep="\t")

# %%
#error
df201_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long02_0_1.csv',sep="\t",skiprows=[i for i in range(1,3)])
df202_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long02_0_2.csv',sep="\t",skiprows=[i for i in range(1,3)])
df203_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long02_0_3.csv',sep="\t",skiprows=[i for i in range(1,3)])
df204_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long02_0_4.csv',sep="\t",skiprows=[i for i in range(1,3)])
df205_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long02_0_5.csv',sep="\t",skiprows=[i for i in range(1,3)])
df206_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long02_0_6.csv',sep="\t",skiprows=[i for i in range(1,3)])
df207_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long02_0_7.csv',sep="\t",skiprows=[i for i in range(1,3)])
df208_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long02_0_8.csv',sep="\t",skiprows=[i for i in range(1,3)])
df209_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long02_0_9.csv',sep="\t",skiprows=[i for i in range(1,3)])
df210_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long02_0_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames2_expand2 = [df201_expand2,df202_expand2,df203_expand2,
          df204_expand2,df205_expand2,df206_expand2,
          df207_expand2,df208_expand2,df209_expand2,
          df210_expand2]

df2_expand2 = pd.concat(frames2_expand2)

dfint2_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long02_0.csv',sep="\t")
#dfint2_expand2_best = pd.read_csv('ernwin-simrna-new_output/CopStems_expand2_2.interaction-csv',sep="\t")

# %%
df201_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long03_0_1.csv',sep="\t",skiprows=[i for i in range(1,3)])
df202_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long03_0_2.csv',sep="\t",skiprows=[i for i in range(1,3)])
df203_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long03_0_3.csv',sep="\t",skiprows=[i for i in range(1,3)])
df204_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long03_0_4.csv',sep="\t",skiprows=[i for i in range(1,3)])
df205_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long03_0_5.csv',sep="\t",skiprows=[i for i in range(1,3)])
df206_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long03_0_6.csv',sep="\t",skiprows=[i for i in range(1,3)])
df207_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long03_0_7.csv',sep="\t",skiprows=[i for i in range(1,3)])
df208_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long03_0_8.csv',sep="\t",skiprows=[i for i in range(1,3)])
df209_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long03_0_9.csv',sep="\t",skiprows=[i for i in range(1,3)])
df210_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long03_0_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames2_expand3 = [df201_expand3,df202_expand3,df203_expand3,
          df204_expand3,df205_expand3,df206_expand3,
          df207_expand3,df208_expand3,df209_expand3,
          df210_expand3]

df2_expand3 = pd.concat(frames2_expand3)

dfint2_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long03_0.csv',sep="\t")
#dfint2_expand3_best = pd.read_csv('ernwin-simrna-new_output/CopStems_expand3_2.interaction-csv',sep="\t")

# %%
#error
df201_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long04_0_1.csv',sep="\t",skiprows=[i for i in range(1,3)])
df202_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long04_0_2.csv',sep="\t",skiprows=[i for i in range(1,3)])
df203_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long04_0_3.csv',sep="\t",skiprows=[i for i in range(1,3)])
df204_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long04_0_4.csv',sep="\t",skiprows=[i for i in range(1,3)])
df205_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long04_0_5.csv',sep="\t",skiprows=[i for i in range(1,3)])
df206_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long04_0_6.csv',sep="\t",skiprows=[i for i in range(1,3)])
df207_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long04_0_7.csv',sep="\t",skiprows=[i for i in range(1,3)])
df208_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long04_0_8.csv',sep="\t",skiprows=[i for i in range(1,3)])
df209_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long04_0_9.csv',sep="\t",skiprows=[i for i in range(1,3)])
df210_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long04_0_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames2_expand4 = [df201_expand4,df202_expand4,df203_expand4,
          df204_expand4,df205_expand4,df206_expand4,
          df207_expand4,df208_expand4,df209_expand4,
          df210_expand4]

df2_expand4 = pd.concat(frames2_expand4)

dfint2_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long04_0.csv',sep="\t")
#dfint2_expand4_best = pd.read_csv('ernwin-simrna-new_output/CopStems_expand4_2.interaction-csv',sep="\t")

# %%
df201_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long05_0_1.csv',sep="\t",skiprows=[i for i in range(1,3)])
df202_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long05_0_2.csv',sep="\t",skiprows=[i for i in range(1,3)])
df203_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long05_0_3.csv',sep="\t",skiprows=[i for i in range(1,3)])
df204_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long05_0_4.csv',sep="\t",skiprows=[i for i in range(1,3)])
df205_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long05_0_5.csv',sep="\t",skiprows=[i for i in range(1,3)])
df206_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long05_0_6.csv',sep="\t",skiprows=[i for i in range(1,3)])
df207_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long05_0_7.csv',sep="\t",skiprows=[i for i in range(1,3)])
df208_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long05_0_8.csv',sep="\t",skiprows=[i for i in range(1,3)])
df209_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long05_0_9.csv',sep="\t",skiprows=[i for i in range(1,3)])
df210_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long05_0_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames2_expand5 = [df201_expand5,df202_expand5,df203_expand5,
          df204_expand5,df205_expand5,df206_expand5,
          df207_expand5,df208_expand5,df209_expand5,
          df210_expand5]

df2_expand5 = pd.concat(frames2_expand5)

dfint2_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long05_0.csv',sep="\t")
#dfint2_expand5_best = pd.read_csv('ernwin-simrna-new_output/CopStems_expand5_2.interaction-csv',sep="\t")

# %%
df201_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long06_0_1.csv',sep="\t",skiprows=[i for i in range(1,3)])
df202_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long06_0_2.csv',sep="\t",skiprows=[i for i in range(1,3)])
df203_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long06_0_3.csv',sep="\t",skiprows=[i for i in range(1,3)])
df204_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long06_0_4.csv',sep="\t",skiprows=[i for i in range(1,3)])
df205_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long06_0_5.csv',sep="\t",skiprows=[i for i in range(1,3)])
df206_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long06_0_6.csv',sep="\t",skiprows=[i for i in range(1,3)])
df207_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long06_0_7.csv',sep="\t",skiprows=[i for i in range(1,3)])
df208_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long06_0_8.csv',sep="\t",skiprows=[i for i in range(1,3)])
df209_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long06_0_9.csv',sep="\t",skiprows=[i for i in range(1,3)])
df210_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long06_0_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames2_expand6 = [df201_expand6,df202_expand6,df203_expand6,
          df204_expand6,df205_expand6,df206_expand6,
          df207_expand6,df208_expand6,df209_expand6,
          df210_expand6]

df2_expand6 = pd.concat(frames2_expand6)

dfint2_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems2_expand_long06_0.csv',sep="\t")
#dfint2_expand6_best = pd.read_csv('ernwin-simrna-new_output/CopStems_expand6_2.interaction-csv',sep="\t")

# %%
df301_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_3_1.csv',sep="\t",skiprows=[i for i in range(1,3)])
df302_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_3_2.csv',sep="\t",skiprows=[i for i in range(1,3)])
df303_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_3_3.csv',sep="\t",skiprows=[i for i in range(1,3)])
df304_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_3_4.csv',sep="\t",skiprows=[i for i in range(1,3)])
df305_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_3_5.csv',sep="\t",skiprows=[i for i in range(1,3)])
df306_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_3_6.csv',sep="\t",skiprows=[i for i in range(1,3)])
df307_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_3_7.csv',sep="\t",skiprows=[i for i in range(1,3)])
df308_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_3_8.csv',sep="\t",skiprows=[i for i in range(1,3)])
df309_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_3_9.csv',sep="\t",skiprows=[i for i in range(1,3)])
df310_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_3_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames3_expand = [df301_expand,df302_expand,df303_expand,
          df304_expand,df305_expand,df306_expand,
          df307_expand,df308_expand,df309_expand,
          df310_expand]

df3_expand = pd.concat(frames3_expand)

dfint3_expand = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_3.csv',sep="\t")
dfint3_expand_best = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_3.interaction-csv',sep="\t")

# %%
df301_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems3_expand_long01_0_1.csv',sep="\t",skiprows=[i for i in range(1,3)])
df302_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems3_expand_long01_0_2.csv',sep="\t",skiprows=[i for i in range(1,3)])
df303_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems3_expand_long01_0_3.csv',sep="\t",skiprows=[i for i in range(1,3)])
df304_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems3_expand_long01_0_4.csv',sep="\t",skiprows=[i for i in range(1,3)])
df305_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems3_expand_long01_0_5.csv',sep="\t",skiprows=[i for i in range(1,3)])
df306_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems3_expand_long01_0_6.csv',sep="\t",skiprows=[i for i in range(1,3)])
df307_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems3_expand_long01_0_7.csv',sep="\t",skiprows=[i for i in range(1,3)])
df308_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems3_expand_long01_0_8.csv',sep="\t",skiprows=[i for i in range(1,3)])
df309_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems3_expand_long01_0_9.csv',sep="\t",skiprows=[i for i in range(1,3)])
df310_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems3_expand_long01_0_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames3_expand1 = [df301_expand1,df302_expand1,df303_expand1,
          df304_expand1,df305_expand1,df306_expand1,
          df307_expand1,df308_expand1,df309_expand1,
          df310_expand1]

df3_expand1 = pd.concat(frames3_expand1)

dfint3_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems3_expand_long01_0.csv',sep="\t")
#dfint3_expand_best = pd.read_csv('ernwin-simrna-new_output/CopStems_expand_3.interaction-csv',sep="\t")

# %%
df101_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long01_0_1.csv',sep="\t",skiprows=[i for i in range(1,3)])
df102_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long01_0_2.csv',sep="\t",skiprows=[i for i in range(1,3)])
df103_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long01_0_3.csv',sep="\t",skiprows=[i for i in range(1,3)])
df104_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long01_0_4.csv',sep="\t",skiprows=[i for i in range(1,3)])
df105_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long01_0_5.csv',sep="\t",skiprows=[i for i in range(1,3)])
df106_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long01_0_6.csv',sep="\t",skiprows=[i for i in range(1,3)])
df107_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long01_0_7.csv',sep="\t",skiprows=[i for i in range(1,3)])
df108_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long01_0_8.csv',sep="\t",skiprows=[i for i in range(1,3)])
df109_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long01_0_9.csv',sep="\t",skiprows=[i for i in range(1,3)])
df110_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long01_0_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames1_expand1 = [df101_expand1,df102_expand1,df103_expand1,
          df104_expand1,df105_expand1,df106_expand1,
          df107_expand1,df108_expand1,df109_expand1,
          df110_expand1]

df1_expand1 = pd.concat(frames1_expand1)

dfint1_expand1 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long01_0.csv',sep="\t")
#dfint3_expand1_best = pd.read_csv('ernwin-simrna-new_output/CopStems_expand1_3.interaction-csv',sep="\t")

# %%
df101_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long02_0_1.csv',sep="\t",skiprows=[i for i in range(1,3)])
df102_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long02_0_2.csv',sep="\t",skiprows=[i for i in range(1,3)])
df103_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long02_0_3.csv',sep="\t",skiprows=[i for i in range(1,3)])
df104_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long02_0_4.csv',sep="\t",skiprows=[i for i in range(1,3)])
df105_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long02_0_5.csv',sep="\t",skiprows=[i for i in range(1,3)])
df106_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long02_0_6.csv',sep="\t",skiprows=[i for i in range(1,3)])
df107_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long02_0_7.csv',sep="\t",skiprows=[i for i in range(1,3)])
df108_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long02_0_8.csv',sep="\t",skiprows=[i for i in range(1,3)])
df109_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long02_0_9.csv',sep="\t",skiprows=[i for i in range(1,3)])
df110_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long02_0_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames1_expand2 = [df101_expand2,df102_expand2,df103_expand2,
          df104_expand2,df105_expand2,df106_expand2,
          df107_expand2,df108_expand2,df109_expand2,
          df110_expand2]

df1_expand2 = pd.concat(frames1_expand2)

dfint1_expand2 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long02_0.csv',sep="\t")
#dfint3_expand3_best = pd.read_csv('ernwin-simrna-new_output/CopStems_expand3_3.interaction-csv',sep="\t")

# %%
df101_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long03_0_1.csv',sep="\t",skiprows=[i for i in range(1,3)])
df102_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long03_0_2.csv',sep="\t",skiprows=[i for i in range(1,3)])
df103_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long03_0_3.csv',sep="\t",skiprows=[i for i in range(1,3)])
df104_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long03_0_4.csv',sep="\t",skiprows=[i for i in range(1,3)])
df105_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long03_0_5.csv',sep="\t",skiprows=[i for i in range(1,3)])
df106_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long03_0_6.csv',sep="\t",skiprows=[i for i in range(1,3)])
df107_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long03_0_7.csv',sep="\t",skiprows=[i for i in range(1,3)])
df108_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long03_0_8.csv',sep="\t",skiprows=[i for i in range(1,3)])
df109_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long03_0_9.csv',sep="\t",skiprows=[i for i in range(1,3)])
df110_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long03_0_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames1_expand3 = [df101_expand3,df102_expand3,df103_expand3,
          df104_expand3,df105_expand3,df106_expand3,
          df107_expand3,df108_expand3,df109_expand3,
          df110_expand3]

df1_expand3 = pd.concat(frames1_expand3)

dfint1_expand3 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long03_0.csv',sep="\t")
#dfint3_expand3_best = pd.read_csv('ernwin-simrna-new_output/CopStems_expand3_3.interaction-csv',sep="\t")

# %%
df101_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long04_0_1.csv',sep="\t",skiprows=[i for i in range(1,3)])
df102_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long04_0_2.csv',sep="\t",skiprows=[i for i in range(1,3)])
df103_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long04_0_3.csv',sep="\t",skiprows=[i for i in range(1,3)])
df104_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long04_0_4.csv',sep="\t",skiprows=[i for i in range(1,3)])
df105_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long04_0_5.csv',sep="\t",skiprows=[i for i in range(1,3)])
df106_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long04_0_6.csv',sep="\t",skiprows=[i for i in range(1,3)])
df107_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long04_0_7.csv',sep="\t",skiprows=[i for i in range(1,3)])
df108_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long04_0_8.csv',sep="\t",skiprows=[i for i in range(1,3)])
df109_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long04_0_9.csv',sep="\t",skiprows=[i for i in range(1,3)])
df110_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long04_0_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames1_expand4 = [df101_expand4,df102_expand4,df103_expand4,
          df104_expand4,df105_expand4,df106_expand4,
          df107_expand4,df108_expand4,df109_expand4,
          df110_expand4]

df1_expand4 = pd.concat(frames1_expand4)

dfint1_expand4 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long04_0.csv',sep="\t")
#dfint3_expand4_best = pd.read_csv('ernwin-simrna-new_output/CopStems_expand4_3.interaction-csv',sep="\t")

# %%
df101_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long05_0_1.csv',sep="\t",skiprows=[i for i in range(1,3)])
df102_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long05_0_2.csv',sep="\t",skiprows=[i for i in range(1,3)])
df103_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long05_0_3.csv',sep="\t",skiprows=[i for i in range(1,3)])
df104_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long05_0_4.csv',sep="\t",skiprows=[i for i in range(1,3)])
df105_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long05_0_5.csv',sep="\t",skiprows=[i for i in range(1,3)])
df106_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long05_0_6.csv',sep="\t",skiprows=[i for i in range(1,3)])
df107_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long05_0_7.csv',sep="\t",skiprows=[i for i in range(1,3)])
df108_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long05_0_8.csv',sep="\t",skiprows=[i for i in range(1,3)])
df109_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long05_0_9.csv',sep="\t",skiprows=[i for i in range(1,3)])
df110_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long05_0_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames1_expand5 = [df101_expand5,df102_expand5,df103_expand5,
          df104_expand5,df105_expand5,df106_expand5,
          df107_expand5,df108_expand5,df109_expand5,
          df110_expand5]

df1_expand5 = pd.concat(frames1_expand5)

dfint1_expand5 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long05_0.csv',sep="\t")
#dfint3_expand5_best = pd.read_csv('ernwin-simrna-new_output/CopStems_expand5_3.interaction-csv',sep="\t")

# %%
df101_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long06_0_1.csv',sep="\t",skiprows=[i for i in range(1,3)])
df102_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long06_0_2.csv',sep="\t",skiprows=[i for i in range(1,3)])
df103_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long06_0_3.csv',sep="\t",skiprows=[i for i in range(1,3)])
df104_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long06_0_4.csv',sep="\t",skiprows=[i for i in range(1,3)])
df105_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long06_0_5.csv',sep="\t",skiprows=[i for i in range(1,3)])
df106_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long06_0_6.csv',sep="\t",skiprows=[i for i in range(1,3)])
df107_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long06_0_7.csv',sep="\t",skiprows=[i for i in range(1,3)])
df108_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long06_0_8.csv',sep="\t",skiprows=[i for i in range(1,3)])
df109_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long06_0_9.csv',sep="\t",skiprows=[i for i in range(1,3)])
df110_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long06_0_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames1_expand6 = [df101_expand6,df102_expand6,df103_expand6,
          df104_expand6,df105_expand6,df106_expand6,
          df107_expand6,df108_expand6,df109_expand6,
          df110_expand6]

df1_expand6 = pd.concat(frames1_expand6)

dfint1_expand6 = pd.read_csv('ernwin-simrna-new_output/CopStems1_expand_long06_0.csv',sep="\t")
#dfint3_expand3_best = pd.read_csv('ernwin-simrna-new_output/CopStems_expand3_3.interaction-csv',sep="\t")

# %%
colorsv=['cornflowerblue','seagreen','lightblue','lightgreen']
colorse=['cornflowerblue','green','orange','red']
palettes={"male": "b", "female": "y"}

def countingfunction1 (count1, count2):
    if count2 == 1:
        count1 += 1
        count2=0
    else:
        count2 += 1
    
    return count1, count2

def countingfunction2(count2):
    if count2 == 1:
        count2 = 0
    else:
        count2 = 1
        
    return count2

def numbers(nr1, nr2, switch):
    if nr2 == 1:
        nr1 += 1
    nr2 = countingfunction2(nr2)
    switch = countingfunction2(switch)
    
    return nr1, nr2, switch

# %%
seq= str('GGGCCCCGGUAAUCUUUUCGUACUCGCCAAAGUUGAAGAAGAUUAUCGGGGUUU CCCCGAUAAUCUUCUUCAACUUUGGCGAGUACGAAAAGAUUACCGGGG')
slist =list(seq)
chainbreak = seq.index(" ")
print ('Chainbreak: {}'.format(chainbreak))
# Out:
# Chainbreak: 54

# %%
fig, ax = plt.subplots(ncols=2)
fig.subplots_adjust(hspace=0.5, wspace=0.5)
fig.suptitle('Soft constrained run (SimRNA) from the inital CopI-CopD simulation run (Ernwin)')


ax[0].set_title('Consecutive interaction bps')
ax[1].set_title('Total interaction length')

ax1 = sns.violinplot(x='len_interaction',y='energy_value', data=df0_surface, 
                     alpha=1, color=colorsv[0], ax=ax[0])
ax2 = sns.violinplot(x='interaction_countbp',y='energy_value', data=df0_surface, 
                     alpha=1, color=colorsv[1],ax=ax[1])
plt.show()
plt.savefig('EMBL-00-surface'+'.png')

# %%
fig, ax = plt.subplots(ncols=2)
fig.subplots_adjust(hspace=0.5, wspace=0.2)
fig.suptitle('1. expansion step: interaction start 3 bps - contraint 5 bp')
ax[0].set_title('Consecutive interaction bps')
ax[1].set_title('Total interaction length')

ax1 = sns.violinplot(x='len_interaction',y='energy_value', data=df1_expand, 
                     alpha=1, color=colorsv[0], ax=ax[0],  bw=0.1)
ax2 = sns.violinplot(x='interaction_countbp',y='energy_value', data=df1_expand, 
                     alpha=1, color=colorsv[1],ax=ax[1],  bw=0.1)

plt.show()
plt.savefig('EMBL-01-expand'+'.png')

# %%
fig, ax = plt.subplots(ncols=2)
fig.subplots_adjust(hspace=0.5, wspace=0.2)
fig.suptitle('2. expansion step: interaction start 5 bps - contraint 7 bp')
ax[0].set_title('Consecutive interaction bps')
ax[1].set_title('Total interaction length')

ax1 = sns.violinplot(x='len_interaction',y='energy_value', data=df2_expand, 
                     alpha=1, color=colorsv[0], ax=ax[0], bw=0.1)
ax2 = sns.violinplot(x='interaction_countbp',y='energy_value', data=df2_expand, 
                     alpha=1, color=colorsv[1],ax=ax[1],  bw=0.1)

plt.show()
plt.savefig('EMBL-02-expand'+'.png')

# %%
fig, ax = plt.subplots(ncols=2)
fig.subplots_adjust(hspace=0.5, wspace=0.2)
fig.suptitle('3. expansion step: interaction start 5 bps - contraint 9 bp')
ax[0].set_title('Consecutive interaction bps')
ax[1].set_title('Total interaction length')

ax1 = sns.violinplot(x='len_interaction',y='energy_value', data=df2_expand, 
                     alpha=1, color=colorsv[0], ax=ax[0], bw=0.1)
ax2 = sns.violinplot(x='interaction_countbp',y='energy_value', data=df2_expand, 
                     alpha=1, color=colorsv[1],ax=ax[1],  bw=0.1)

plt.show()
plt.savefig('EMBL-03-expand'+'.png')

# %%
y=[0,1, 2, 3]
x=[22389,21477,22953,17130]


plt.xlim(0,40000)
plt.ylim(-1,4)

y_pos = np.arange(len(y))
 
plt.barh(y, x)
 
plt.yticks(y_pos, y,color='cornflowerblue' )

for i, v in enumerate(x):
    if i ==0:
        plt.text(v + 500, i-0.1, str(v), color='cornflowerblue', fontweight='bold')
    else:
        plt.text(v + 500, i-0.1, str(v), color='cornflowerblue', fontweight='bold')
    
plt.xlabel('Structure Diversity')
plt.ylabel('Simulationstep')
 
plt.show()

# %%
y=[0,1, 2, 3]
x=[308,20,10,8]
text=['308, dif. 0 bps','20, dif. 2 bps', '10, dif. 5 bps', '8, dif. 5bps']


plt.xlim(0,500)
plt.ylim(-1,4)

y_pos = np.arange(len(y))
 
plt.barh(y, x)
 
plt.yticks(y_pos, y,color='cornflowerblue' )
for i, v in enumerate(x):
    plt.text(v + 5, i-0.1, str(text[i]), color='cornflowerblue', fontweight='bold',fontsize =14)

    
plt.xlabel('Best to Constraint')
plt.ylabel('Simulationstep')
 
plt.show()

# %%
y=[0,1, 2, 3]
x=[308,271,45,583]


plt.xlim(0,700)
plt.ylim(-1,4)

y_pos = np.arange(len(y))
 
plt.barh(y, x)
 
plt.yticks(y_pos, y,color='cornflowerblue' )
for i, v in enumerate(x):
    plt.text(v + 10, i-0.1, str(x[i]), color='cornflowerblue', fontweight='bold')
    
plt.xlabel('Starting Structure')
plt.ylabel('Simulationstep')
 
plt.show()

# %%
#plt.rcParams['figure.figsize'] = [15, 3]

cl = dfint0_surface.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()
plt.ylim(-1350,-700)

#ax.set_title('Soft constrained run (SimRNA) from the inital CopI-CopD simulation (Ernwin)')

ax = sns.violinplot(x='len_interaction',y='energy_value', data=df0_surface, alpha=1, color=colorsv[0], ax=ax)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
plt.savefig('EMBL-00-surface_2'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 0        5
# 1     1239
# 2     9343
# 3    41435
# 4    47988
# Name: count_how_often, dtype: int64>

# %%
cl = dfint1_expand.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()
plt.ylim(-1350,-1000)

#ax.set_title('1. expansion step: interaction start 3 bps - contraint 5 bps')

ax = sns.violinplot(x='len_interaction',y='energy_value', data=df1_expand, 
                     alpha=1, color=colorsv[0], ax=ax,  bw=0.1)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
plt.savefig('EMBL-01-expand2'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 1      332
# 2     1505
# 3    32352
# 4    47968
# 5    13298
# 6     4555
# Name: count_how_often, dtype: int64>

# %%
cl = dfint2_expand.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()
plt.ylim(-1350,-1000)

#ax.set_title('2. expansion step: interaction start 5 bps - contraint 7 bps')
ax = sns.violinplot(x='len_interaction',y='energy_value', data=df2_expand, 
                     alpha=1, color=colorsv[0], ax=ax, bw=0.1)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
plt.savefig('EMBL-02-expand2'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 1        3
# 2      804
# 3     5051
# 4    44119
# 5    48485
# 6     1548
# Name: count_how_often, dtype: int64>

# %%
cl = dfint3_expand.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()
plt.ylim(-1350,-1000)

#ax.set_title('3. expansion step: interaction start 5 bps - contraint 9 bps')

ax = sns.violinplot(x='len_interaction',y='energy_value', data=df2_expand, 
                     alpha=1, color=colorsv[0], ax=ax, bw=0.1)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
#plt.savefig('EMBL-03-expand2'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 2      185
# 3     1648
# 4     3278
# 5    14052
# 6    80847
# Name: count_how_often, dtype: int64>

# %%
cl = dfint3_expand1.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()

#ax.set_title('2. expansion step: interaction start 5 bps - contraint 7 bps')
ax = sns.violinplot(x='len_interaction',y='energy_value', data=df3_expand1, 
                     alpha=1, color=colorsv[0], ax=ax, bw=0.1)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
#plt.savefig('EMBL-02-expand1'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 1        27
# 2       465
# 3      3430
# 4      8819
# 5     37714
# 6    149555
# Name: count_how_often, dtype: int64>

# %%
#old but important
df301_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_01.csv',sep="\t",skiprows=[i for i in range(1,3)])
df302_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_02.csv',sep="\t",skiprows=[i for i in range(1,3)])
df303_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_03.csv',sep="\t",skiprows=[i for i in range(1,3)])
df304_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_04.csv',sep="\t",skiprows=[i for i in range(1,3)])
df305_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_05.csv',sep="\t",skiprows=[i for i in range(1,3)])
df306_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_06.csv',sep="\t",skiprows=[i for i in range(1,3)])
df307_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_07.csv',sep="\t",skiprows=[i for i in range(1,3)])
df308_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_08.csv',sep="\t",skiprows=[i for i in range(1,3)])
df309_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_09.csv',sep="\t",skiprows=[i for i in range(1,3)])
df310_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames3_expandheavy = [df301_expandheavy,df302_expandheavy,df303_expandheavy,
          df304_expandheavy,df305_expandheavy,df306_expandheavy,
          df307_expandheavy,df308_expandheavy,df309_expandheavy,
          df310_expandheavy]

df3_expandheavy = pd.concat(frames3_expandheavy)

dfint3_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03.csv',sep="\t")
dfint3_expandheavy_best = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03.interaction-csv',sep="\t")


cl = dfint3_expandheavy.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()
plt.ylim(-1350,-700)

#ax.set_title('3. expansion step: interaction start 5 bps - contraint 9 bps')

ax = sns.violinplot(x='len_interaction',y='energy_value', data=df3_expandheavy, 
                     alpha=1, color=colorsv[0], ax=ax, bw=0.1)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
plt.savefig('EMBL-03-expandheavy'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 1       26
# 2      320
# 3      911
# 4     6114
# 5    21740
# 6    63063
# 7     7528
# 8      308
# Name: count_how_often, dtype: int64>

# %%
df01_8bp_expand = pd.read_csv('SimRNA_output/CopStems8bp_expand_04_01.csv',sep="\t",skiprows=[i for i in range(1,3)])
df02_8bp_expand = pd.read_csv('SimRNA_output/CopStems8bp_expand_04_02.csv',sep="\t",skiprows=[i for i in range(1,3)])
df03_8bp_expand = pd.read_csv('SimRNA_output/CopStems8bp_expand_04_03.csv',sep="\t",skiprows=[i for i in range(1,3)])
df04_8bp_expand = pd.read_csv('SimRNA_output/CopStems8bp_expand_04_04.csv',sep="\t",skiprows=[i for i in range(1,3)])
df05_8bp_expand = pd.read_csv('SimRNA_output/CopStems8bp_expand_04_05.csv',sep="\t",skiprows=[i for i in range(1,3)])
df06_8bp_expand = pd.read_csv('SimRNA_output/CopStems8bp_expand_04_06.csv',sep="\t",skiprows=[i for i in range(1,3)])
df07_8bp_expand = pd.read_csv('SimRNA_output/CopStems8bp_expand_04_07.csv',sep="\t",skiprows=[i for i in range(1,3)])
df08_8bp_expand = pd.read_csv('SimRNA_output/CopStems8bp_expand_04_08.csv',sep="\t",skiprows=[i for i in range(1,3)])
df09_8bp_expand = pd.read_csv('SimRNA_output/CopStems8bp_expand_04_09.csv',sep="\t",skiprows=[i for i in range(1,3)])
df10_8bp_expand = pd.read_csv('SimRNA_output/CopStems8bp_expand_04_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames_8bp_expand = [df01_8bp_expand,df02_8bp_expand,df03_8bp_expand,
              df04_8bp_expand,df05_8bp_expand,df06_8bp_expand,
              df07_8bp_expand,df08_8bp_expand,df09_8bp_expand,
              df10_8bp_expand]

df_8bp_expand = pd.concat(frames_8bp_expand)


dfint_8bp_expand = pd.read_csv('SimRNA_output/CopStems8bp_expand_04.csv',sep="\t")
dfint_8bp_expand_best = pd.read_csv('SimRNA_output/CopStems8bp_expand_04.interaction-csv',sep="\t")


cl = dfint_8bp_expand.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()
plt.ylim(-1350,-1000)

#ax.set_title('3. expansion step: interaction start 5 bps - contraint 9 bps')

ax = sns.violinplot(x='len_interaction',y='energy_value', data=df_8bp_expand, 
                     alpha=1, color=colorsv[0], ax=ax, bw=0.1)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
plt.savefig('EMBL-8bp_expand'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 2       44
# 3      372
# 4     2250
# 5     3372
# 6     6910
# 7     6944
# 8    80118
# Name: count_how_often, dtype: int64>

# %%
df01_3_3buffer = pd.read_csv('SimRNA_output/CopStems3buffer_2rl_03_01.csv',sep="\t",skiprows=[i for i in range(1,3)])
df02_3_3buffer = pd.read_csv('SimRNA_output/CopStems3buffer_2rl_03_02.csv',sep="\t",skiprows=[i for i in range(1,3)])
df03_3_3buffer = pd.read_csv('SimRNA_output/CopStems3buffer_2rl_03_03.csv',sep="\t",skiprows=[i for i in range(1,3)])
df04_3_3buffer = pd.read_csv('SimRNA_output/CopStems3buffer_2rl_03_04.csv',sep="\t",skiprows=[i for i in range(1,3)])
df05_3_3buffer = pd.read_csv('SimRNA_output/CopStems3buffer_2rl_03_05.csv',sep="\t",skiprows=[i for i in range(1,3)])
df06_3_3buffer = pd.read_csv('SimRNA_output/CopStems3buffer_2rl_03_06.csv',sep="\t",skiprows=[i for i in range(1,3)])
df07_3_3buffer = pd.read_csv('SimRNA_output/CopStems3buffer_2rl_03_07.csv',sep="\t",skiprows=[i for i in range(1,3)])
df08_3_3buffer = pd.read_csv('SimRNA_output/CopStems3buffer_2rl_03_08.csv',sep="\t",skiprows=[i for i in range(1,3)])
df09_3_3buffer = pd.read_csv('SimRNA_output/CopStems3buffer_2rl_03_09.csv',sep="\t",skiprows=[i for i in range(1,3)])
df10_3_3buffer = pd.read_csv('SimRNA_output/CopStems3buffer_2rl_03_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames_3_3buffer = [df01_3_3buffer,df02_3_3buffer,df03_3_3buffer,
              df04_3_3buffer,df05_3_3buffer,df06_3_3buffer,
              df07_3_3buffer,df08_3_3buffer,df09_3_3buffer,
              df10_3_3buffer]

df_3_3buffer = pd.concat(frames_3_3buffer)


dfint_3_3buffer = pd.read_csv('SimRNA_output/CopStems3buffer_2rl_03.csv',sep="\t")
#dfint_3_3buffer_best = pd.read_csv('SimRNA_output/CopStems3_3buffer_04.interaction-csv',sep="\t")


cl = dfint_3_3buffer.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()
plt.ylim(-1350,-1000)

#ax.set_title('3. expansion step: interaction start 5 bps - contraint 9 bps')

ax = sns.violinplot(x='len_interaction',y='energy_value', data=df_3_3buffer, 
                     alpha=1, color=colorsv[0], ax=ax, bw=0.1)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
#plt.savefig('EMBL-3_3buffer'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 3       21
# 4      938
# 5    13477
# 6    85574
# Name: count_how_often, dtype: int64>

# %%
df01_3_4buffer = pd.read_csv('SimRNA_output/CopStems4buffer_2rl_03_01.csv',sep="\t",skiprows=[i for i in range(1,3)])
df02_3_4buffer = pd.read_csv('SimRNA_output/CopStems4buffer_2rl_03_02.csv',sep="\t",skiprows=[i for i in range(1,3)])
df03_3_4buffer = pd.read_csv('SimRNA_output/CopStems4buffer_2rl_03_03.csv',sep="\t",skiprows=[i for i in range(1,3)])
df04_3_4buffer = pd.read_csv('SimRNA_output/CopStems4buffer_2rl_03_04.csv',sep="\t",skiprows=[i for i in range(1,3)])
df05_3_4buffer = pd.read_csv('SimRNA_output/CopStems4buffer_2rl_03_05.csv',sep="\t",skiprows=[i for i in range(1,3)])
df06_3_4buffer = pd.read_csv('SimRNA_output/CopStems4buffer_2rl_03_06.csv',sep="\t",skiprows=[i for i in range(1,3)])
df07_3_4buffer = pd.read_csv('SimRNA_output/CopStems4buffer_2rl_03_07.csv',sep="\t",skiprows=[i for i in range(1,3)])
df08_3_4buffer = pd.read_csv('SimRNA_output/CopStems4buffer_2rl_03_08.csv',sep="\t",skiprows=[i for i in range(1,3)])
df09_3_4buffer = pd.read_csv('SimRNA_output/CopStems4buffer_2rl_03_09.csv',sep="\t",skiprows=[i for i in range(1,3)])
df10_3_4buffer = pd.read_csv('SimRNA_output/CopStems4buffer_2rl_03_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames_3_4buffer = [df01_3_4buffer,df02_3_4buffer,df03_3_4buffer,
              df04_3_4buffer,df05_3_4buffer,df06_3_4buffer,
              df07_3_4buffer,df08_3_4buffer,df09_3_4buffer,
              df10_3_4buffer]

df_3_4buffer = pd.concat(frames_3_4buffer)


dfint_3_4buffer = pd.read_csv('SimRNA_output/CopStems4buffer_2rl_03.csv',sep="\t")
#dfint_3_4buffer_best = pd.read_csv('SimRNA_output/CopStems3_4buffer_04.interaction-csv',sep="\t")


cl = dfint_3_4buffer.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()
plt.ylim(-1350,-1000)

#ax.set_title('3. expansion step: interaction start 5 bps - contraint 9 bps')

ax = sns.violinplot(x='len_interaction',y='energy_value', data=df_3_4buffer, 
                     alpha=1, color=colorsv[0], ax=ax)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
#plt.savefig('EMBL-3_4buffer'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 2        3
# 3       54
# 4     1259
# 5    17233
# 6    81461
# Name: count_how_often, dtype: int64>

# %%
df01_3_right = pd.read_csv('SimRNA_output/CopStemsright_2rl_03_01.csv',sep="\t",skiprows=[i for i in range(1,3)])
df02_3_right = pd.read_csv('SimRNA_output/CopStemsright_2rl_03_02.csv',sep="\t",skiprows=[i for i in range(1,3)])
df03_3_right = pd.read_csv('SimRNA_output/CopStemsright_2rl_03_03.csv',sep="\t",skiprows=[i for i in range(1,3)])
df04_3_right = pd.read_csv('SimRNA_output/CopStemsright_2rl_03_04.csv',sep="\t",skiprows=[i for i in range(1,3)])
df05_3_right = pd.read_csv('SimRNA_output/CopStemsright_2rl_03_05.csv',sep="\t",skiprows=[i for i in range(1,3)])
df06_3_right = pd.read_csv('SimRNA_output/CopStemsright_2rl_03_06.csv',sep="\t",skiprows=[i for i in range(1,3)])
df07_3_right = pd.read_csv('SimRNA_output/CopStemsright_2rl_03_07.csv',sep="\t",skiprows=[i for i in range(1,3)])
df08_3_right = pd.read_csv('SimRNA_output/CopStemsright_2rl_03_08.csv',sep="\t",skiprows=[i for i in range(1,3)])
df09_3_right = pd.read_csv('SimRNA_output/CopStemsright_2rl_03_09.csv',sep="\t",skiprows=[i for i in range(1,3)])
df10_3_right = pd.read_csv('SimRNA_output/CopStemsright_2rl_03_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames_3_right = [df01_3_right,df02_3_right,df03_3_right,
              df04_3_right,df05_3_right,df06_3_right,
              df07_3_right,df08_3_right,df09_3_right,
              df10_3_right]

df_3_right = pd.concat(frames_3_right)


dfint_3_right = pd.read_csv('SimRNA_output/CopStemsright_2r_03.csv',sep="\t")
#dfint_3_right_best = pd.read_csv('SimRNA_output/CopStems3_right_04.interaction-csv',sep="\t")


cl = dfint_3_right.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()
plt.ylim(-1350,-1000)

#ax.set_title('3. expansion step: interaction start 5 bps - contraint 9 bps')

ax = sns.violinplot(x='len_interaction',y='energy_value', data=df_3_right, 
                     alpha=1, color=colorsv[0], ax=ax, bw=0.1)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
#plt.savefig('EMBL-3_right'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 3       53
# 4     1361
# 5    16997
# 6    81599
# Name: count_how_often, dtype: int64>

# %%
df01_3_left = pd.read_csv('SimRNA_output/CopStemsleft_2rl_03_01.csv',sep="\t",skiprows=[i for i in range(1,3)])
df02_3_left = pd.read_csv('SimRNA_output/CopStemsleft_2rl_03_02.csv',sep="\t",skiprows=[i for i in range(1,3)])
df03_3_left = pd.read_csv('SimRNA_output/CopStemsleft_2rl_03_03.csv',sep="\t",skiprows=[i for i in range(1,3)])
df04_3_left = pd.read_csv('SimRNA_output/CopStemsleft_2rl_03_04.csv',sep="\t",skiprows=[i for i in range(1,3)])
df05_3_left = pd.read_csv('SimRNA_output/CopStemsleft_2rl_03_05.csv',sep="\t",skiprows=[i for i in range(1,3)])
df06_3_left = pd.read_csv('SimRNA_output/CopStemsleft_2rl_03_06.csv',sep="\t",skiprows=[i for i in range(1,3)])
df07_3_left = pd.read_csv('SimRNA_output/CopStemsleft_2rl_03_07.csv',sep="\t",skiprows=[i for i in range(1,3)])
df08_3_left = pd.read_csv('SimRNA_output/CopStemsleft_2rl_03_08.csv',sep="\t",skiprows=[i for i in range(1,3)])
df09_3_left = pd.read_csv('SimRNA_output/CopStemsleft_2rl_03_09.csv',sep="\t",skiprows=[i for i in range(1,3)])
df10_3_left = pd.read_csv('SimRNA_output/CopStemsleft_2rl_03_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames_3_left = [df01_3_left,df02_3_left,df03_3_left,
              df04_3_left,df05_3_left,df06_3_left,
              df07_3_left,df08_3_left,df09_3_left,
              df10_3_left]

df_3_left = pd.concat(frames_3_left)


dfint_3_left = pd.read_csv('SimRNA_output/CopStemsleft_2l_03.csv',sep="\t")
#dfint_3_left_best = pd.read_csv('SimRNA_output/CopStems3_left_04.interaction-csv',sep="\t")


cl = dfint_3_left.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()
plt.ylim(-1350,-1000)

#ax.set_title('3. expansion step: interaction start 5 bps - contraint 9 bps')

ax = sns.violinplot(x='len_interaction',y='energy_value', data=df_3_left, 
                     alpha=1, color=colorsv[0], ax=ax)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
#plt.savefig('EMBL-3_left'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 2        3
# 3       55
# 4     1198
# 5    15399
# 6    83355
# Name: count_how_often, dtype: int64>

# %%
cl = dfint2_expand01.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()

#ax.set_title('2. expansion step: interaction start 5 bps - contraint 7 bps')
ax = sns.violinplot(x='len_interaction',y='energy_value', data=df2_expand01, 
                     alpha=1, color=colorsv[0], ax=ax, bw=0.1)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
#plt.savefig('EMBL-02-expand1'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 1      116
# 2     1667
# 3    12067
# 4    78393
# 5    92047
# 6    15720
# Name: count_how_often, dtype: int64>

# %%
cl = dfint2_expand2.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()

#ax.set_title('2. expansion step: interaction start 5 bps - contraint 7 bps')
ax = sns.violinplot(x='len_interaction',y='energy_value', data=df2_expand2, 
                     alpha=1, color=colorsv[0], ax=ax, bw=0.1)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
#plt.savefig('EMBL-02-expand1'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 1       79
# 2     1991
# 3    14476
# 4    72405
# 5    91055
# Name: count_how_often, dtype: int64>

# %%
cl = dfint2_expand3.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()

#ax.set_title('2. expansion step: interaction start 5 bps - contraint 7 bps')
ax = sns.violinplot(x='len_interaction',y='energy_value', data=df2_expand3, 
                     alpha=1, color=colorsv[0], ax=ax, bw=0.1)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
#plt.savefig('EMBL-02-expand1'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 1       2
# 2      41
# 3     229
# 4    2353
# 5    4651
# 6    2734
# Name: count_how_often, dtype: int64>

# %%
cl = dfint2_expand4.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()

#ax.set_title('2. expansion step: interaction start 5 bps - contraint 7 bps')
ax = sns.violinplot(x='len_interaction',y='energy_value', data=df2_expand4, 
                     alpha=1, color=colorsv[0], ax=ax, bw=0.1)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
#plt.savefig('EMBL-02-expand1'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 1        79
# 2      2280
# 3     15565
# 4     79492
# 5    108603
# 6      6991
# Name: count_how_often, dtype: int64>

# %%
cl = dfint1_expand1.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()
plt.ylim(-1350,-1000)

#ax.set_title('2. expansion step: interaction start 5 bps - contraint 7 bps')
ax = sns.violinplot(x='len_interaction',y='energy_value', data=df1_expand1, 
                     alpha=1, color=colorsv[0], ax=ax, bw=0.1)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
#plt.savefig('EMBL-02-expand1'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 1       361
# 2      2659
# 3     40756
# 4    101912
# 5     42396
# 6     11926
# Name: count_how_often, dtype: int64>

# %%
cl = dfint1_expand2.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()
plt.ylim(-1350,-1000)

#ax.set_title('2. expansion step: interaction start 5 bps - contraint 7 bps')
ax = sns.violinplot(x='len_interaction',y='energy_value', data=df1_expand2, 
                     alpha=1, color=colorsv[0], ax=ax)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
#plt.savefig('EMBL-02-expand1'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 1        332
# 2       4142
# 3      61068
# 4     173121
# 5      55589
# 6       5756
# 15         2
# Name: count_how_often, dtype: int64>

# %%
cl = dfint1_expand3.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()
plt.ylim(-1350,-1000)

#ax.set_title('2. expansion step: interaction start 5 bps - contraint 7 bps')
ax = sns.violinplot(x='len_interaction',y='energy_value', data=df1_expand3, 
                     alpha=1, color=colorsv[0], ax=ax, bw=0.1)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
#plt.savefig('EMBL-02-expand1'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 1       3
# 2      56
# 3     532
# 4    2578
# 5    3031
# 6    3810
# Name: count_how_often, dtype: int64>

# %%
cl = dfint1_expand4.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()
plt.ylim(-1350,-1100)

#ax.set_title('2. expansion step: interaction start 5 bps - contraint 7 bps')
ax = sns.violinplot(x='len_interaction',y='energy_value', data=df1_expand4, 
                     alpha=1, color=colorsv[0], ax=ax, bw=0.1)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
#plt.savefig('EMBL-02-expand1'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 1        6
# 2       92
# 3     1014
# 4     3522
# 5     5716
# 6    19660
# Name: count_how_often, dtype: int64>

# %%
cl = dfint1_expand5.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()
plt.ylim(-1350,-1100)

#ax.set_title('2. expansion step: interaction start 5 bps - contraint 7 bps')
ax = sns.violinplot(x='len_interaction',y='energy_value', data=df1_expand5, 
                     alpha=1, color=colorsv[0], ax=ax, bw=0.1)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
#plt.savefig('EMBL-02-expand1'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 1        7
# 2      126
# 3     1504
# 4     5476
# 5    12529
# 6    40368
# Name: count_how_often, dtype: int64>

# %%
cl = dfint1_expand6.groupby('len_interaction')['count_how_often'].sum().to_dict
print(cl)

fig, ax = plt.subplots()
plt.ylim(-1350,-1100)

#ax.set_title('2. expansion step: interaction start 5 bps - contraint 7 bps')
ax = sns.violinplot(x='len_interaction',y='energy_value', data=df1_expand6, 
                     alpha=1, color=colorsv[0], ax=ax, bw=0.1)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

for plt.show()
#plt.savefig('EMBL-02-expand1'+'.png')
# Out:
# <bound method Series.to_dict of len_interaction
# 1        5
# 2      174
# 3     2112
# 4     6438
# 5    16377
# 6    72399
# 7     2505
# Name: count_how_often, dtype: int64>

# %%
fig, ax = plt.subplots()

for interlen in enumerate(6):
    df.loc[df1_expand6['len_interaction'].isin(interlen)]
    ax.set_ylim(0, 10000) # how often
    ax.set_xlim(0,10000) # time
    
    
    




#cl = dfint1_expand6.groupby('len_interaction')['count_how_often'].sum().to_dict
#print(cl)

fig, ax = plt.subplots()
#plt.ylim(-1350,-1100)

#ax.set_title('2. expansion step: interaction start 5 bps - contraint 7 bps')
ax = sns.violinplot(x='len_interaction',y='energy_value', data=df1_expand6, 
                     alpha=1, color=colorsv[0], ax=ax, bw=0.1)
ax.set(xlabel='Interaction Length (bps)', ylabel='Energy (SimRNA)')

plt.show()
#plt.savefig('EMBL-02-expand1'+'.png')


fig, ax = plt.subplots()
for nm in ['Wind', 'Solar', 'Wind+Solar']:
    ax.plot(opsd_365d[nm], label=nm)
    # Set x-ticks to yearly interval, adjust y-axis limits, add legend and labels
    ax.xaxis.set_major_locator(mdates.YearLocator())
    ax.set_ylim(0, 400)
    ax.legend()
    ax.set_ylabel('Production (GWh)')
    ax.set_title('Trends in Electricity Production (365-d Rolling Means)');
