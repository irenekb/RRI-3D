# %%
# %matplotlib tk
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
import glob, os
import seaborn as sns
import matplotlib.ticker as plticker
warnings.simplefilter("ignore")
plt.rcParams['figure.figsize'] = [15, 5]

# %%
dfbp0_surface = pd.read_csv('SimRNA_output/CopStems_surface_00.csv_bp',sep="\t")
print (dfbp0_surface)

dfbp1_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_01.csv_bp',sep="\t")
dfbp1_expand = pd.read_csv('SimRNA_output/CopStems_expand_01.csv_bp',sep="\t")
dfbp1_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_01.csv_bp',sep="\t")

dfbp2_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_01.csv_bp',sep="\t")
dfbp2_expand = pd.read_csv('SimRNA_output/CopStems_expand_02.csv_bp',sep="\t")
dfbp2_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_02.csv_bp',sep="\t")

dfbp3_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_03.csv_bp',sep="\t")
dfbp3_expand = pd.read_csv('SimRNA_output/CopStems_expand_03.csv_bp',sep="\t")
dfbp3_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_03.csv_bp',sep="\t")

dfbp3_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03.csv_bp',sep="\t")
dfbp_8pb = pd.read_csv('SimRNA_output/CopStems8bp_surface_04.csv_bp',sep="\t")
# Out:
#     nr  bp1  bp2      count
# 0    0    2   51  365000284
# 1    1   64   93  442902131
# 2    2   69   89  356210306
# 3    3   17   36   80717624
# 4    4   17   35  422763352
# ..  ..  ...  ...        ...
# 76  76   16   37  167086335
# 77  77    0   53  384827230
# 78  78   14   38   33278128
# 79  79   25   80  446883494
# 80  80   70   87     346079
#
# [81 rows x 4 columns]

# %%
#Load al Files, sort them and put them into dataframes
df001_surface = pd.read_csv('SimRNA_output/CopStems_surface_00_01.csv',sep="\t",skiprows=[i for i in range(1,3)])
df002_surface = pd.read_csv('SimRNA_output/CopStems_surface_00_02.csv',sep="\t",skiprows=[i for i in range(1,3)])
df003_surface = pd.read_csv('SimRNA_output/CopStems_surface_00_03.csv',sep="\t",skiprows=[i for i in range(1,3)])
df004_surface = pd.read_csv('SimRNA_output/CopStems_surface_00_04.csv',sep="\t",skiprows=[i for i in range(1,3)])
df005_surface = pd.read_csv('SimRNA_output/CopStems_surface_00_05.csv',sep="\t",skiprows=[i for i in range(1,3)])
df006_surface = pd.read_csv('SimRNA_output/CopStems_surface_00_06.csv',sep="\t",skiprows=[i for i in range(1,3)])
df007_surface = pd.read_csv('SimRNA_output/CopStems_surface_00_07.csv',sep="\t",skiprows=[i for i in range(1,3)])
df008_surface = pd.read_csv('SimRNA_output/CopStems_surface_00_08.csv',sep="\t",skiprows=[i for i in range(1,3)])
df009_surface = pd.read_csv('SimRNA_output/CopStems_surface_00_09.csv',sep="\t",skiprows=[i for i in range(1,3)])
df010_surface = pd.read_csv('SimRNA_output/CopStems_surface_00_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames00_surface = [df001_surface,df002_surface,df003_surface,df004_surface,df005_surface,df006_surface,df007_surface,df008_surface,df009_surface,df010_surface]

df0_surface = pd.concat(frames00_surface)

dfint0_surface = pd.read_csv('SimRNA_output/CopStems_surface_00.csv',sep="\t")
dfint0_surface_best = pd.read_csv('SimRNA_output/CopStems_surface_00.interaction-csv',sep="\t")

# %%
df101_expand = pd.read_csv('SimRNA_output/CopStems_expand_01_01.csv',sep="\t",skiprows=[i for i in range(1,3)])
df102_expand = pd.read_csv('SimRNA_output/CopStems_expand_01_02.csv',sep="\t",skiprows=[i for i in range(1,3)])
df103_expand = pd.read_csv('SimRNA_output/CopStems_expand_01_03.csv',sep="\t",skiprows=[i for i in range(1,3)])
df104_expand = pd.read_csv('SimRNA_output/CopStems_expand_01_04.csv',sep="\t",skiprows=[i for i in range(1,3)])
df105_expand = pd.read_csv('SimRNA_output/CopStems_expand_01_05.csv',sep="\t",skiprows=[i for i in range(1,3)])
df106_expand = pd.read_csv('SimRNA_output/CopStems_expand_01_06.csv',sep="\t",skiprows=[i for i in range(1,3)])
df107_expand = pd.read_csv('SimRNA_output/CopStems_expand_01_07.csv',sep="\t",skiprows=[i for i in range(1,3)])
df108_expand = pd.read_csv('SimRNA_output/CopStems_expand_01_08.csv',sep="\t",skiprows=[i for i in range(1,3)])
df109_expand = pd.read_csv('SimRNA_output/CopStems_expand_01_09.csv',sep="\t",skiprows=[i for i in range(1,3)])
df110_expand = pd.read_csv('SimRNA_output/CopStems_expand_01_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames1_expand = [df101_expand,df102_expand,df103_expand,
          df104_expand,df105_expand,df106_expand,
          df107_expand,df108_expand,df109_expand,
          df110_expand]

df1_expand = pd.concat(frames1_expand)

dfint1_expand = pd.read_csv('SimRNA_output/CopStems_expand_01.csv',sep="\t")
dfint1_expand_best = pd.read_csv('SimRNA_output/CopStems_expand_01.interaction-csv',sep="\t")

# %%
df101_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_01_01.csv',sep="\t",skiprows=[i for i in range(1,3)])
df102_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_01_02.csv',sep="\t",skiprows=[i for i in range(1,3)])
df103_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_01_03.csv',sep="\t",skiprows=[i for i in range(1,3)])
df104_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_01_04.csv',sep="\t",skiprows=[i for i in range(1,3)])
df105_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_01_05.csv',sep="\t",skiprows=[i for i in range(1,3)])
df106_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_01_06.csv',sep="\t",skiprows=[i for i in range(1,3)])
df107_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_01_07.csv',sep="\t",skiprows=[i for i in range(1,3)])
df108_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_01_08.csv',sep="\t",skiprows=[i for i in range(1,3)])
df109_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_01_09.csv',sep="\t",skiprows=[i for i in range(1,3)])
df110_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_01_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames1_expand00 = [df101_expand00,df102_expand00,df103_expand00,
          df104_expand00,df105_expand00,df106_expand00,
          df107_expand00,df108_expand00,df109_expand00,
          df110_expand00]

df1_expand00 = pd.concat(frames1_expand00)

dfint1_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_01.csv',sep="\t")
dfint1_expand00_best = pd.read_csv('SimRNA_output/CopStems_expand_long00_01.interaction-csv',sep="\t")

# %%
df101_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_01_01.csv',sep="\t",skiprows=[i for i in range(1,3)])
df102_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_01_02.csv',sep="\t",skiprows=[i for i in range(1,3)])
df103_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_01_03.csv',sep="\t",skiprows=[i for i in range(1,3)])
df104_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_01_04.csv',sep="\t",skiprows=[i for i in range(1,3)])
df105_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_01_05.csv',sep="\t",skiprows=[i for i in range(1,3)])
df106_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_01_06.csv',sep="\t",skiprows=[i for i in range(1,3)])
df107_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_01_07.csv',sep="\t",skiprows=[i for i in range(1,3)])
df108_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_01_08.csv',sep="\t",skiprows=[i for i in range(1,3)])
df109_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_01_09.csv',sep="\t",skiprows=[i for i in range(1,3)])
df110_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_01_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames1_expandsurface = [df101_expandsurface,df102_expandsurface,df103_expandsurface,
          df104_expandsurface,df105_expandsurface,df106_expandsurface,
          df107_expandsurface,df108_expandsurface,df109_expandsurface,
          df110_expandsurface]

df1_expandsurface = pd.concat(frames1_expandsurface)

dfint1_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_01.csv',sep="\t")
dfint1_expandsurface_best = pd.read_csv('SimRNA_output/CopStems_expand_surface_01.interaction-csv',sep="\t")

# %%
df201_expand = pd.read_csv('SimRNA_output/CopStems_expand_02_01.csv',sep="\t",skiprows=[i for i in range(1,3)])
df202_expand = pd.read_csv('SimRNA_output/CopStems_expand_02_02.csv',sep="\t",skiprows=[i for i in range(1,3)])
df203_expand = pd.read_csv('SimRNA_output/CopStems_expand_02_03.csv',sep="\t",skiprows=[i for i in range(1,3)])
df204_expand = pd.read_csv('SimRNA_output/CopStems_expand_02_04.csv',sep="\t",skiprows=[i for i in range(1,3)])
df205_expand = pd.read_csv('SimRNA_output/CopStems_expand_02_05.csv',sep="\t",skiprows=[i for i in range(1,3)])
df206_expand = pd.read_csv('SimRNA_output/CopStems_expand_02_06.csv',sep="\t",skiprows=[i for i in range(1,3)])
df207_expand = pd.read_csv('SimRNA_output/CopStems_expand_02_07.csv',sep="\t",skiprows=[i for i in range(1,3)])
df208_expand = pd.read_csv('SimRNA_output/CopStems_expand_02_08.csv',sep="\t",skiprows=[i for i in range(1,3)])
df209_expand = pd.read_csv('SimRNA_output/CopStems_expand_02_09.csv',sep="\t",skiprows=[i for i in range(1,3)])
df210_expand = pd.read_csv('SimRNA_output/CopStems_expand_02_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames2_expand = [df201_expand,df202_expand,df203_expand,
          df204_expand,df205_expand,df206_expand,
          df207_expand,df208_expand,df209_expand,
          df210_expand]

df2_expand = pd.concat(frames2_expand)

dfint2_expand = pd.read_csv('SimRNA_output/CopStems_expand_02.csv',sep="\t")
dfint2_expand_best = pd.read_csv('SimRNA_output/CopStems_expand_02.interaction-csv',sep="\t")

# %%
df201_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_02_01.csv',sep="\t",skiprows=[i for i in range(1,3)])
df202_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_02_02.csv',sep="\t",skiprows=[i for i in range(1,3)])
df203_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_02_03.csv',sep="\t",skiprows=[i for i in range(1,3)])
df204_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_02_04.csv',sep="\t",skiprows=[i for i in range(1,3)])
df205_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_02_05.csv',sep="\t",skiprows=[i for i in range(1,3)])
df206_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_02_06.csv',sep="\t",skiprows=[i for i in range(1,3)])
df207_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_02_07.csv',sep="\t",skiprows=[i for i in range(1,3)])
df208_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_02_08.csv',sep="\t",skiprows=[i for i in range(1,3)])
df209_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_02_09.csv',sep="\t",skiprows=[i for i in range(1,3)])
df210_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_02_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames2_expand00 = [df201_expand00,df202_expand00,df203_expand00,
          df204_expand00,df205_expand00,df206_expand00,
          df207_expand00,df208_expand00,df209_expand00,
          df210_expand00]

df2_expand00 = pd.concat(frames2_expand00)

dfint2_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_02.csv',sep="\t")
dfint2_expand00_best = pd.read_csv('SimRNA_output/CopStems_expand_long00_02.interaction-csv',sep="\t")

# %%
df201_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_02_01.csv',sep="\t",skiprows=[i for i in range(1,3)])
df202_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_02_02.csv',sep="\t",skiprows=[i for i in range(1,3)])
df203_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_02_03.csv',sep="\t",skiprows=[i for i in range(1,3)])
df204_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_02_04.csv',sep="\t",skiprows=[i for i in range(1,3)])
df205_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_02_05.csv',sep="\t",skiprows=[i for i in range(1,3)])
df206_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_02_06.csv',sep="\t",skiprows=[i for i in range(1,3)])
df207_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_02_07.csv',sep="\t",skiprows=[i for i in range(1,3)])
df208_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_02_08.csv',sep="\t",skiprows=[i for i in range(1,3)])
df209_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_02_09.csv',sep="\t",skiprows=[i for i in range(1,3)])
df210_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_02_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames2_expandsurface = [df201_expandsurface,df202_expandsurface,df203_expandsurface,
          df204_expandsurface,df205_expandsurface,df206_expandsurface,
          df207_expandsurface,df208_expandsurface,df209_expandsurface,
          df210_expandsurface]

df2_expandsurface = pd.concat(frames2_expandsurface)

dfint2_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_02.csv',sep="\t")
dfint2_expandsurface_best = pd.read_csv('SimRNA_output/CopStems_expand_surface_02.interaction-csv',sep="\t")

# %%
df301_expand = pd.read_csv('SimRNA_output/CopStems_expand_03_01.csv',sep="\t",skiprows=[i for i in range(1,3)])
df302_expand = pd.read_csv('SimRNA_output/CopStems_expand_03_02.csv',sep="\t",skiprows=[i for i in range(1,3)])
df303_expand = pd.read_csv('SimRNA_output/CopStems_expand_03_03.csv',sep="\t",skiprows=[i for i in range(1,3)])
df304_expand = pd.read_csv('SimRNA_output/CopStems_expand_03_04.csv',sep="\t",skiprows=[i for i in range(1,3)])
df305_expand = pd.read_csv('SimRNA_output/CopStems_expand_03_05.csv',sep="\t",skiprows=[i for i in range(1,3)])
df306_expand = pd.read_csv('SimRNA_output/CopStems_expand_03_06.csv',sep="\t",skiprows=[i for i in range(1,3)])
df307_expand = pd.read_csv('SimRNA_output/CopStems_expand_03_07.csv',sep="\t",skiprows=[i for i in range(1,3)])
df308_expand = pd.read_csv('SimRNA_output/CopStems_expand_03_08.csv',sep="\t",skiprows=[i for i in range(1,3)])
df309_expand = pd.read_csv('SimRNA_output/CopStems_expand_03_09.csv',sep="\t",skiprows=[i for i in range(1,3)])
df310_expand = pd.read_csv('SimRNA_output/CopStems_expand_03_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames3_expand = [df301_expand,df302_expand,df303_expand,
          df304_expand,df305_expand,df306_expand,
          df307_expand,df308_expand,df309_expand,
          df310_expand]

df3_expand = pd.concat(frames3_expand)

dfint3_expand = pd.read_csv('SimRNA_output/CopStems_expand_03.csv',sep="\t")
dfint3_expand_best = pd.read_csv('SimRNA_output/CopStems_expand_03.interaction-csv',sep="\t")

# %%
df301_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_03_01.csv',sep="\t",skiprows=[i for i in range(1,3)])
df302_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_03_02.csv',sep="\t",skiprows=[i for i in range(1,3)])
df303_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_03_03.csv',sep="\t",skiprows=[i for i in range(1,3)])
df304_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_03_04.csv',sep="\t",skiprows=[i for i in range(1,3)])
df305_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_03_05.csv',sep="\t",skiprows=[i for i in range(1,3)])
df306_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_03_06.csv',sep="\t",skiprows=[i for i in range(1,3)])
df307_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_03_07.csv',sep="\t",skiprows=[i for i in range(1,3)])
df308_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_03_08.csv',sep="\t",skiprows=[i for i in range(1,3)])
df309_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_03_09.csv',sep="\t",skiprows=[i for i in range(1,3)])
df310_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_03_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames3_expand00 = [df301_expand00,df302_expand00,df303_expand00,
          df304_expand00,df305_expand00,df306_expand00,
          df307_expand00,df308_expand00,df309_expand00,
          df310_expand00]

df3_expand00 = pd.concat(frames3_expand00)

dfint3_expand00 = pd.read_csv('SimRNA_output/CopStems_expand_long00_03.csv',sep="\t")
dfint3_expand00_best = pd.read_csv('SimRNA_output/CopStems_expand_long00_03.interaction-csv',sep="\t")

# %%
df301_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_03_01.csv',sep="\t",skiprows=[i for i in range(1,3)])
df302_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_03_02.csv',sep="\t",skiprows=[i for i in range(1,3)])
df303_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_03_03.csv',sep="\t",skiprows=[i for i in range(1,3)])
df304_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_03_04.csv',sep="\t",skiprows=[i for i in range(1,3)])
df305_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_03_05.csv',sep="\t",skiprows=[i for i in range(1,3)])
df306_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_03_06.csv',sep="\t",skiprows=[i for i in range(1,3)])
df307_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_03_07.csv',sep="\t",skiprows=[i for i in range(1,3)])
df308_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_03_08.csv',sep="\t",skiprows=[i for i in range(1,3)])
df309_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_03_09.csv',sep="\t",skiprows=[i for i in range(1,3)])
df310_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_03_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames3_expandsurface = [df301_expandsurface,df302_expandsurface,df303_expandsurface,
          df304_expandsurface,df305_expandsurface,df306_expandsurface,
          df307_expandsurface,df308_expandsurface,df309_expandsurface,
          df310_expandsurface]

df3_expandsurface = pd.concat(frames3_expandsurface)

dfint3_expandsurface = pd.read_csv('SimRNA_output/CopStems_expand_surface_03.csv',sep="\t")
dfint3_expandsurface_best = pd.read_csv('SimRNA_output/CopStems_expand_surface_03.interaction-csv',sep="\t")

# %%
df301_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_01.csv',sep="\t",skiprows=[i for i in range(1,3)])
df302_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_02.csv',sep="\t",skiprows=[i for i in range(1,3)])
df303_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_03.csv',sep="\t",skiprows=[i for i in range(1,3)])
df304_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_04.csv',sep="\t",skiprows=[i for i in range(1,3)])
df305_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_05.csv',sep="\t",skiprows=[i for i in range(1,3)])
df306_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_06.csv',sep="\t",skiprows=[i for i in range(1,3)])
df307_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_07.csv',sep="\t",skiprows=[i for i in range(1,3)])
df308_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_08.csv',sep="\t",skiprows=[i for i in range(1,3)])
df309_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_09.csv',sep="\t",skiprows=[i for i in range(1,3)])
df310_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames3_expandheavy = [df301_expandheavy,df302_expandheavy,df303_expandheavy,
          df304_expandheavy,df305_expandheavy,df306_expandheavy,
          df307_expandheavy,df308_expandheavy,df309_expandheavy,
          df310_expandheavy]

df3_expandheavy = pd.concat(frames3_expandheavy)

dfint3_expandheavy = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03.csv',sep="\t")
dfint3_expandheavy_best = pd.read_csv('SimRNA_output/CopStemsHeavy_expand_03.interaction-csv',sep="\t")

# %%
df01_8bp = pd.read_csv('SimRNA_output/CopStems8bp_surface_04_01.csv',sep="\t",skiprows=[i for i in range(1,3)])
df02_8bp = pd.read_csv('SimRNA_output/CopStems8bp_surface_04_02.csv',sep="\t",skiprows=[i for i in range(1,3)])
df03_8bp = pd.read_csv('SimRNA_output/CopStems8bp_surface_04_03.csv',sep="\t",skiprows=[i for i in range(1,3)])
df04_8bp = pd.read_csv('SimRNA_output/CopStems8bp_surface_04_04.csv',sep="\t",skiprows=[i for i in range(1,3)])
df05_8bp = pd.read_csv('SimRNA_output/CopStems8bp_surface_04_05.csv',sep="\t",skiprows=[i for i in range(1,3)])
df06_8bp = pd.read_csv('SimRNA_output/CopStems8bp_surface_04_06.csv',sep="\t",skiprows=[i for i in range(1,3)])
df07_8bp = pd.read_csv('SimRNA_output/CopStems8bp_surface_04_07.csv',sep="\t",skiprows=[i for i in range(1,3)])
df08_8bp = pd.read_csv('SimRNA_output/CopStems8bp_surface_04_08.csv',sep="\t",skiprows=[i for i in range(1,3)])
df09_8bp = pd.read_csv('SimRNA_output/CopStems8bp_surface_04_09.csv',sep="\t",skiprows=[i for i in range(1,3)])
df10_8bp = pd.read_csv('SimRNA_output/CopStems8bp_surface_04_10.csv',sep="\t",skiprows=[i for i in range(1,3)])

frames_8bp = [df01_8bp,df02_8bp,df03_8bp,
          df04_8bp,df05_8bp,df06_8bp,
          df07_8bp,df08_8bp,df09_8bp,
          df10_8bp]

df_8bp = pd.concat(frames_8bp)

dfint_8bp = pd.read_csv('SimRNA_output/CopStems8bp_surface_04.csv',sep="\t")
dfint_8bp_best = pd.read_csv('SimRNA_output/CopStems8bp_surface_04.interaction-csv',sep="\t")

# %%
colorsv=['cornflowerblue','seagreen','lightblue','lightgreen']
colorse=['cornflowerblue','green','orange','red']
palettes={"male": "b", "female": "y"}

def countingfunction1 (count1, count2):
    if count2 == 1:
        count1 += 1
        count2=0
    else:
        count2 += 1
    
    return count1, count2

def countingfunction2(count2):
    if count2 == 1:
        count2 = 0
    else:
        count2 = 1
        
    return count2

def numbers(nr1, nr2, switch):
    if nr2 == 1:
        nr1 += 1
    nr2 = countingfunction2(nr2)
    switch = countingfunction2(switch)
    
    return nr1, nr2, switch

# %%
seq= str('GGGCCCCGGUAAUCUUUUCGUACUCGCCAAAGUUGAAGAAGAUUAUCGGGGUUU CCCCGAUAAUCUUCUUCAACUUUGGCGAGUACGAAAAGAUUACCGGGG')
slist =list(seq)
chainbreak = seq.index(" ")
print ('Chainbreak: {}'.format(chainbreak))
# Out:
# Chainbreak: 54

# %%
print('SURFACE RUN FROM INITIAL RUN - single RUNS')
print('constraint (3) --> surface 10,0000 without constraint')
print('((((((((((((((((((((.(((......))))))).)))))))))))))))) (((((.(((((((.(((.((((....))))..)))))))))).)))))')
print('.........................(((.......................... .......................)))......................')

fig, ax = plt.subplots(nrows=10, ncols=2,figsize=[100,80])
fig.subplots_adjust(hspace=0.8, wspace=0.4)


titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= ['interaction_countbp','len_interaction']
yval = str('energy_value')

switch = 0
figpos1 = 0
figpos2 = 0
majortitle=str('SURFACE RUN FROM INITIAL RUN - single RUNS')

for n, df in enumerate(frames00_surface):
    fig.suptitle(majortitle)
    #ax[figpos1,figpos2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)
    
    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
    #ax[figpos1,figpos2].set_title(titles[n])
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)

    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)

plt.show()
plt.savefig('00-surface_' + str(1) + '.png')
# Out:
# SURFACE RUN FROM INITIAL RUN - single RUNS
# constraint (3) --> surface 10,0000 without constraint
# ((((((((((((((((((((.(((......))))))).)))))))))))))))) (((((.(((((((.(((.((((....))))..)))))))))).)))))
# .........................(((.......................... .......................)))......................

# %%
plt.rcParams['figure.figsize'] = [15, 5]
fig, ax = plt.subplots(nrows=2,figsize=[80,60])
fig.subplots_adjust(hspace=0.5, wspace=0.2)
xval= ['interaction_countbp','len_interaction']
#yval = str('energy_value')
majortitle=str('SURFACE RUN FROM INITIAL RUN - single RUNS')
ranges=[0,1000,]

count1, count2 = 0,0
ax.set_xlim([0,8])
ax.set_ylim([0,10000])

n=1000
for nr in range(1000,10000,1000):
    df1 = df[df['number'] <= nr]
    
    
    
    
    
    fig.suptitle(majortitle)
    ax[count1,count2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = df.plot(x=xval,y=yval, alpha=1, c=colorse[0], linewidth=0.5,  ax=ax[count1,count2], ylim=[-1350,-1100])
    
    df1 = df[df['count_interaction_constraint'] == 0]
    axname = df1.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[1], s=50, ax=ax[count1,count2])
    
    df2 = df[df['count_constraint']<=3]
    axname = df2.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[2], marker='x',s=100, ax=ax[count1,count2])

    if n == run:
        axname = best3d.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[3],marker='x', s=100, ax=ax[count1,count2])
        
    count1,count2 = countingfunction1(count1,count2)
    
plt.show()
#plt.savefig('00-surface_' + str(2) + '.png')

# %%
#Extract the trafl-name and the list number from the .ss_detected name
best3d = (dfint0_surface_best.head(1))
name = best3d.iloc[:,0].to_string(index=False).strip()
print('Best structure: {}'.format(name))
print('Energy: {}'.format(best3d.iloc[0]['energy_value']))
print('Interactionlength: {}, StackingBPs: {}'.format(best3d.iloc[0]['len_interaction'],best3d.iloc[0]['interaction_countbp']))
run = int(name.split('.')[0].split('_')[3])-1 #iterate dfs starts with 0


plt.rcParams['figure.figsize'] = [15, 5]
fig, ax = plt.subplots(nrows=5, ncols=2,figsize=[80,60])
fig.subplots_adjust(hspace=0.5, wspace=0.2)
titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= str('time')
yval = str('energy_value')
majortitle=str('SURFACE RUN FROM INITIAL RUN - single RUNS, interaction_constraint=0, count constraint<=3')

count1, count2 = 0,0

for n, df in enumerate(frames00_surface):
    fig.suptitle(majortitle)
    ax[count1,count2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = df.plot(x=xval,y=yval, alpha=1, c=colorse[0], linewidth=0.5,  ax=ax[count1,count2], ylim=[-1350,-1100])
    
    df1 = df[df['count_interaction_constraint'] == 0]
    axname = df1.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[1], s=50, ax=ax[count1,count2])
    
    df2 = df[df['count_constraint']<=3]
    axname = df2.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[2], marker='x',s=100, ax=ax[count1,count2])

    if n == run:
        axname = best3d.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[3],marker='x', s=100, ax=ax[count1,count2])
        
    count1,count2 = countingfunction1(count1,count2)
    
plt.show()
plt.savefig('00-surface_' + str(2) + '.png')
# Out:
# Best structure: CopStems_surface_00_2_2-007006.ss_detected
# Energy: -1232.33044
# Interactionlength: 3, StackingBPs: 3

# %%
print('SURFACE RUN FROM INITIAL RUN - summary')
print('constraint (3) --> surface 10,0000')
print('((((((((((((((((((((.(((......))))))).)))))))))))))))) (((((.(((((((.(((.((((....))))..)))))))))).)))))')
print('.........................(((.......................... .......................)))......................')

fig, ax = plt.subplots(nrows=4,figsize=[100,80])
fig.subplots_adjust(hspace=0.5, wspace=0.2)

fig.suptitle('SURFACE RUN FROM INITIAL RUN - summary')
ax1 = sns.violinplot(x='interaction_countbp',y='energy_value', data=df0_surface, 
                     alpha=1, color=colorsv[0], ax=ax[0],  bw=0.1)
ax2 = sns.violinplot(x='interaction_countbp',y='energy_values_plus_restraint_score', data=df0_surface, 
                     alpha=1, color=colorsv[2], ax=ax[1],  bw=0.1)

ax3 = sns.violinplot(x='len_interaction',y='energy_value', data=df0_surface, 
                     alpha=1, color=colorsv[1],ax=ax[2],  bw=0.1)
ax2 = sns.violinplot(x='interaction_countbp',y='energy_values_plus_restraint_score', data=df0_surface, 
                     alpha=1, color=colorsv[3], ax=ax[3],  bw=0.1)

plt.show()
plt.savefig('00-surface_' + str(3) + '.png')
# Out:
# SURFACE RUN FROM INITIAL RUN - summary
# constraint (3) --> surface 10,0000
# ((((((((((((((((((((.(((......))))))).)))))))))))))))) (((((.(((((((.(((.((((....))))..)))))))))).)))))
# .........................(((.......................... .......................)))......................

# %%
ax = dfbp0_surface.plot.hexbin(x='bp1',y='bp2', C='count', alpha=1,  gridsize=70, cmap="viridis")

fig.suptitle('SURFACE RUN FROM INITIAL RUN - summary')
xticklabels = slist
ax.set_xticks(np.arange(len(slist)))
ax.set_xticklabels(xticklabels)

yticklabels = slist
ax.set_yticks(np.arange(len(slist)))
ax.set_yticklabels(xticklabels)

ax.grid(axis='both',color='grey',linestyle='-', linewidth=0.5, alpha=0.2)
ax.tick_params(axis='both', which='both', labelleft='on', labelright='on',labelbottom='on',labeltop='on')


ax.set_aspect("equal")
ax.set_title("gridsize=100")
ax.axvline(x=chainbreak)
ax.axhline(y=chainbreak)

plt.show()
plt.savefig('00-surface_' + str(4) + '.png')

# %%
print('SINGLE RUNS - Expand 5.000steps')
print('start structure')
print('((((((((((((((((((((.(((......))))))).)))))))))))))))) (((.(.((((((..(((.(((......)))..))).)))))).).)))')
print('................(....................)................ ................................................')
print('.........................(((.......................... .......................)))......................')
print()

print('constraint (5):')
print('((((((((((((((((((((.(..........))))).)))))))))))))))) (((((.(((((((.(((.(..........)..)))))))))).)))))')
print('........................(((((......................... ......................))))).....................')


fig, ax = plt.subplots(nrows=10, ncols=2,figsize=[100,80])
fig.subplots_adjust(hspace=0.8, wspace=0.4)
fig.suptitle('EXPAND 5,000 RUN 3 --> 5 - single runs')

colorsv=['cornflowerblue','seagreen']

titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= ['interaction_countbp','len_interaction']
yval = str('energy_value')

switch = 0
figpos1 = 0
figpos2 = 0


for n, df in enumerate(frames1_expand00):
    #ax[figpos1,figpos2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)
    
    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
    #ax[figpos1,figpos2].set_title(titles[n])
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)

    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)

plt.show()
plt.savefig('01-expand00' + str(1) + '.png')
# Out:
# SINGLE RUNS - Expand 5.000steps
# start structure
# ((((((((((((((((((((.(((......))))))).)))))))))))))))) (((.(.((((((..(((.(((......)))..))).)))))).).)))
# ................(....................)................ ................................................
# .........................(((.......................... .......................)))......................
#
# constraint (5):
# ((((((((((((((((((((.(..........))))).)))))))))))))))) (((((.(((((((.(((.(..........)..)))))))))).)))))
# ........................(((((......................... ......................))))).....................

# %%
#Extract the trafl-name and the list number from the .ss_detected name
best3d = (dfint1_expand00_best.head(1))
name = best3d.iloc[:,0].to_string(index=False).strip()
print('Best structure: {}'.format(name))
print('Energy: {}'.format(best3d.iloc[0]['energy_value']))
run = int(name.split('.')[0].split('_')[3])-1 #iterate dfs starts with 0

plt.rcParams['figure.figsize'] = [15, 5]
fig, ax = plt.subplots(nrows=5, ncols=2,figsize=[80,60])
fig.subplots_adjust(hspace=0.5, wspace=0.2)
titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= str('time')
yval = str('energy_value')
fig.suptitle('EXPAND 5,000 RUN 3 --> 5 - single runs, interaction_constraint=0, count constraint<=3')

count1, count2 = 0,0

for n, df in enumerate(frames1_expand00):
    
    ax[count1,count2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = df.plot(x=xval,y=yval, alpha=1, c=colorse[0], linewidth=0.5,  ax=ax[count1,count2], ylim=[-1350,-1100])
    
    df1 = df[df['count_interaction_constraint'] == 0]
    axname = df1.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[1], s=10, ax=ax[count1,count2])
    
    df2 = df[df['count_constraint']<=3]
    axname = df2.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[2], marker='x',s=100, ax=ax[count1,count2])

    if n == run:
        axname = best3d.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[3],marker='x', s=100, ax=ax[count1,count2])
        
    count1,count2 = countingfunction1(count1,count2)
    
plt.show()
plt.savefig('01-expand00' + str(2) + '.png')
# Out:
# Best structure: CopStems_expand_long00_01_4_4-001743.ss_detected
# Energy: -1250.531301

# %%
print('SINGLE RUNS - Expand 10.000steps')
print('start structure')
print('((((((((((((((((((((.(((......))))))).)))))))))))))))) (((.(.((((((..(((.(((......)))..))).)))))).).)))')
print('................(....................)................ ................................................')
print('.........................(((.......................... .......................)))......................')
print()

print('constraint (5):')
print('((((((((((((((((((((.(..........))))).)))))))))))))))) (((((.(((((((.(((.(..........)..)))))))))).)))))')
print('........................(((((......................... ......................))))).....................')


fig, ax = plt.subplots(nrows=10, ncols=2,figsize=[100,80])
fig.subplots_adjust(hspace=0.8, wspace=0.4)

colorsv=['cornflowerblue','seagreen']

titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= ['interaction_countbp','len_interaction']
yval = str('energy_value')
fig.suptitle('EXPAND 10,000 RUN 3 --> 5 - single runs')

plt.savefig('01-expand' + str(2) + '.png')

switch = 0
figpos1 = 0
figpos2 = 0


for n, df in enumerate(frames1_expand):
    #ax[figpos1,figpos2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)
    
    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
    #ax[figpos1,figpos2].set_title(titles[n])
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)

    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)

    
plt.show()
plt.savefig('01-expand' + str(1) + '.png')
# Out:
# SINGLE RUNS - Expand 10.000steps
# start structure
# ((((((((((((((((((((.(((......))))))).)))))))))))))))) (((.(.((((((..(((.(((......)))..))).)))))).).)))
# ................(....................)................ ................................................
# .........................(((.......................... .......................)))......................
#
# constraint (5):
# ((((((((((((((((((((.(..........))))).)))))))))))))))) (((((.(((((((.(((.(..........)..)))))))))).)))))
# ........................(((((......................... ......................))))).....................

# %%
#Extract the trafl-name and the list number from the .ss_detected name
best3d = (dfint1_expand_best.head(1))
name = best3d.iloc[:,0].to_string(index=False).strip()
print('Best structure: {}'.format(name))
print('Energy: {}'.format(best3d.iloc[0]['energy_value']))
run = int(name.split('.')[0].split('_')[3])-1 #iterate dfs starts with 0


plt.rcParams['figure.figsize'] = [15, 5]
fig, ax = plt.subplots(nrows=5, ncols=2,figsize=[80,60])
fig.subplots_adjust(hspace=0.5, wspace=0.2)
titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= str('time')
yval = str('energy_value')
fig.suptitle('EXPAND 10,000 RUN 3 --> 5 - single runs, interaction_constraint=0, count constraint<=3')

count1, count2 = 0,0

for n, df in enumerate(frames1_expand):
    
    ax[count1,count2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = df.plot(x=xval,y=yval, alpha=1, c=colorse[0], linewidth=0.5,  ax=ax[count1,count2], ylim=[-1350,-1100])
    
    df1 = df[df['count_interaction_constraint'] == 0]
    axname = df1.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[1], s=10, ax=ax[count1,count2])
    
    df2 = df[df['count_constraint']<=3]
    axname = df2.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[2], marker='x',s=100, ax=ax[count1,count2])

    if n == run:
        axname = best3d.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[3],marker='x', s=100, ax=ax[count1,count2])
        
    count1,count2 = countingfunction1(count1,count2)
    
plt.show()
plt.savefig('01-expand' + str(2) + '.png')
# Out:
# Best structure: CopStems_expand_01_4_4-004929.ss_detected
# Energy: -1221.4106800000004

# %%
print('SINGLE RUNS - SurfaceExpand (10.000steps)')

fig, ax = plt.subplots(nrows=10, ncols=2,figsize=[100,80])
fig.subplots_adjust(hspace=0.8, wspace=0.4)

colorsv=['cornflowerblue','seagreen']

titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= ['interaction_countbp','len_interaction']
yval = str('energy_value')
fig.suptitle('EXPANDSURFACE 10,000 RUN 3 --> 5')

switch = 0
figpos1 = 0
figpos2 = 0

for n, df in enumerate(frames1_expandsurface):
    #ax[figpos1,figpos2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)
    
    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
    #ax[figpos1,figpos2].set_title(titles[n])
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)

    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
plt.show()
plt.savefig('01-expandsurface' + str(1) + '.png')
# Out:
# SINGLE RUNS - SurfaceExpand (10.000steps)

# %%
#Extract the trafl-name and the list number from the .ss_detected name
best3d = (dfint1_expandsurface_best.head(1))
name = best3d.iloc[:,0].to_string(index=False).strip()
print('Best structure: {}'.format(name))
print('Energy: {}'.format(best3d.iloc[0]['energy_value']))
print('Interactionlength: {}, StackingBPs: {}'.format(best3d.iloc[0]['len_interaction'],best3d.iloc[0]['interaction_countbp']))
run = int(name.split('.')[0].split('_')[3])-1 #iterate dfs starts with 0

plt.rcParams['figure.figsize'] = [15, 5]
fig, ax = plt.subplots(nrows=5, ncols=2,figsize=[80,60])
fig.subplots_adjust(hspace=0.5, wspace=0.2)
titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= str('time')
yval = str('energy_value')
fig.suptitle('EXPANDSURFACE 10,000 RUN 3 --> 5 - single runs, interaction_constraint=0, count constraint<=3')

count1, count2 = 0,0

for n, df in enumerate(frames1_expandsurface):
    
    ax[count1,count2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = df.plot(x=xval,y=yval, alpha=1, c=colorse[0], linewidth=0.5,  ax=ax[count1,count2], ylim=[-1350,-1100])
    
    df1 = df[df['count_interaction_constraint'] == 0]
    axname = df1.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[1], s=10, ax=ax[count1,count2])
    
    df2 = df[df['count_constraint']<=3]
    axname = df2.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[2], marker='x',s=100, ax=ax[count1,count2])

    if n == run:
        axname = best3d.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[3],marker='x', s=100, ax=ax[count1,count2])
        
    count1,count2 = countingfunction1(count1,count2)
    
plt.show()
plt.savefig('01-expandsurface' + str(2) + '.png')
# Out:
# Best structure: CopStems_expand_surface_01_3_3-008261.ss_detected
# Energy: -1257.140082
# Interactionlength: 5, StackingBPs: 5

# %%
print('start structure')
print('((((((((((((((((((((.(((......))))))).)))))))))))))))) (((.(.((((((..(((.(((......)))..))).)))))).).)))')
print('................(....................)................ ................................................')
print('.........................(((.......................... .......................)))......................')
print()
print('constraint (5):')
print('((((((((((((((((((((.(..........))))).)))))))))))))))) (((((.(((((((.(((.(..........)..)))))))))).)))))')
print('........................(((((......................... ......................))))).....................')
print()
print('SURFACE RUN FROM INITIAL RUN - summary')
print('constraint (3) --> surface 10,0000')
print('((((((((((((((((((((.(((......))))))).)))))))))))))))) (((((.(((((((.(((.((((....))))..)))))))))).)))))')
print('.........................(((.......................... .......................)))......................')

fig, ax = plt.subplots(nrows=6, ncols=2,figsize=[20,15])
fig.subplots_adjust(hspace=0.8, wspace=0.4)
fig.suptitle('EXPAND from 3 --> 5 - summary')

titles=['5,000 steps','10,000 steps','surface']
xval= ['interaction_countbp','len_interaction']
yval = ['energy_value','energy_values_plus_restraint_score']

for i in range(6):
    for j in range(2):
        if i == 0 or i == 1:
            ax[i,j].set_title(titles[0])
        elif i == 2 or i == 3:
            ax[i,j].set_title(titles[1])
        else:
            ax[i,j].set_title(titles[2])

ax1 = sns.violinplot(x=xval[0],y=yval[0], data=df1_expand00, color=colorsv[0], ax=ax[0,0], bw=0.1)
ax2 = sns.violinplot(x=xval[0],y=yval[1], data=df1_expand00, color=colorsv[2], ax=ax[1,0], bw=0.1)

ax3 = sns.violinplot(x=xval[1],y=yval[0], data=df1_expand00, color=colorsv[1], ax=ax[0,1], bw=0.1)
ax4 = sns.violinplot(x=xval[1],y=yval[1], data=df1_expand00, color=colorsv[3], ax=ax[1,1], bw=0.1)

ax5 = sns.violinplot(x=xval[0],y=yval[0], data=df1_expand, color=colorsv[0], ax=ax[2,0], bw=0.1)
ax6 = sns.violinplot(x=xval[0],y=yval[1], data=df1_expand, color=colorsv[2], ax=ax[3,0], bw=0.1)

ax7 = sns.violinplot(x=xval[1],y=yval[0], data=df1_expand, color=colorsv[1], ax=ax[2,1], bw=0.1)
ax8 = sns.violinplot(x=xval[1],y=yval[1], data=df1_expand, color=colorsv[3], ax=ax[3,1], bw=0.1)

ax9 = sns.violinplot(x=xval[0],y=yval[0], data=df1_expandsurface, color=colorsv[0], ax=ax[4,0], bw=0.1)
ax10 = sns.violinplot(x=xval[0],y=yval[1], data=df1_expandsurface, color=colorsv[2], ax=ax[5,0], bw=0.1)

ax11 = sns.violinplot(x=xval[1],y=yval[0], data=df1_expandsurface, color=colorsv[1], ax=ax[4,1], bw=0.1)
ax12 = sns.violinplot(x=xval[1],y=yval[1], data=df1_expandsurface, color=colorsv[3], ax=ax[5,1], bw=0.1)

plt.show()
plt.savefig('01-expandsummary' + str() + '.png')
# Out:
# start structure
# ((((((((((((((((((((.(((......))))))).)))))))))))))))) (((.(.((((((..(((.(((......)))..))).)))))).).)))
# ................(....................)................ ................................................
# .........................(((.......................... .......................)))......................
#
# constraint (5):
# ((((((((((((((((((((.(..........))))).)))))))))))))))) (((((.(((((((.(((.(..........)..)))))))))).)))))
# ........................(((((......................... ......................))))).....................
#
# SURFACE RUN FROM INITIAL RUN - summary
# constraint (3) --> surface 10,0000
# ((((((((((((((((((((.(((......))))))).)))))))))))))))) (((((.(((((((.(((.((((....))))..)))))))))).)))))
# .........................(((.......................... .......................)))......................

# %%
titles=['5,000 steps','10,000 steps','surface']

for nr, plot in enumerate(titles):
    #ax.set_xlim([0,len(slist)])
    #ax.set_ylim([0,len(slist)])

    if nr == 0:
        fig.suptitle('EXPAND 5,000 RUN 3 --> 5')
        ax = dfbp1_expand00.plot.hexbin(x='bp1',y='bp2', C='count',alpha=1,  gridsize=70, cmap="viridis",title=titles[nr])
        name =str('01-expand00' + str(4) + '.png')
        
    if nr == 1:
        fig.suptitle('EXPAND 10,000 RUN 3 --> 5')
        ax = dfbp1_expand.plot.hexbin(x='bp1',y='bp2', C='count', alpha=1,  gridsize=70, cmap="viridis",title=titles[nr])
        name =str('01-expand' + str(4) + '.png')
        
    if nr == 2:
        fig.suptitle('EXPANDSURFACE 5,000 RUN 3 --> 5')
        ax = dfbp1_expandsurface.plot.hexbin(x='bp1',y='bp2', C='count', alpha=1,  gridsize=70, cmap="viridis",title=titles[nr])
        name =str('01-expandsurface' + str(4) + '.png')
        
    xticklabels = slist
    ax.set_xticks(np.arange(len(slist)))
    ax.set_xticklabels(xticklabels)

    yticklabels = slist
    ax.set_yticks(np.arange(len(slist)))
    ax.set_yticklabels(xticklabels)
  
    ax.tick_params(axis='both', which='both', labelleft='on', labelright='on',labelbottom='on',labeltop='on')
    ax.grid(axis='both',color='grey',linestyle='-', linewidth=0.5, alpha=0.2)

    ax.set_aspect("equal")
    ax.axvline(x=chainbreak)
    ax.axhline(y=chainbreak)
    #ax.plot(ax.get_xlim(), ax.get_ylim(), ls="--", c=".3")
    
    plt.show()
    plt.savefig(name)

# %%
print('SINGLE RUNS - 2 - EXPAND 5.000 steps')
print('start structure')
print('((((((((((((((((((((.((........)))))).)))))))))))))))) (((.(.(((((((.(((.((........))..)))))))))).).)))')
print('........................(((((......................... ......................))))).....................')
print()
print('constraint (7):')
print('((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))')
print('.......................(((((((........................ .....................)))))))....................')

fig, ax = plt.subplots(nrows=10, ncols=2,figsize=[100,80])
fig.subplots_adjust(hspace=0.8, wspace=0.4)

titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= ['interaction_countbp','len_interaction']
yval = str('energy_value')
fig.suptitle('EXPAND 5,000 RUN 5 --> 7 - single runs')

switch = 0
figpos1 = 0
figpos2 = 0

for n, df in enumerate(frames2_expand00):
    #ax[figpos1,figpos2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)
    
    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
    #ax[figpos1,figpos2].set_title(titles[n])
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)

    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
plt.show()
plt.savefig('02-expand00' + str(1) + '.png')
# Out:
# SINGLE RUNS - 2 - EXPAND 5.000 steps
# start structure
# ((((((((((((((((((((.((........)))))).)))))))))))))))) (((.(.(((((((.(((.((........))..)))))))))).).)))
# ........................(((((......................... ......................))))).....................
#
# constraint (7):
# ((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))
# .......................(((((((........................ .....................)))))))....................

# %%
#Extract the trafl-name and the list number from the .ss_detected name
best3d = (dfint2_expand00_best.head(1))
name = best3d.iloc[:,0].to_string(index=False).strip()
print('Best structure: {}'.format(name))
print('Energy: {}'.format(best3d.iloc[0]['energy_value']))
print('Interactionlength: {}, StackingBPs: {}'.format(best3d.iloc[0]['len_interaction'],best3d.iloc[0]['interaction_countbp']))
run = int(name.split('.')[0].split('_')[3])-1 #iterate dfs starts with 0

plt.rcParams['figure.figsize'] = [15, 5]
fig, ax = plt.subplots(nrows=5, ncols=2,figsize=[80,60])
fig.subplots_adjust(hspace=0.5, wspace=0.2)
titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= str('time')
yval = str('energy_value')
fig.suptitle('EXPAND 5,000 RUN 3 --> 5 - single runs, interaction_constraint=0, count constraint<=6')

count1, count2 = 0,0

for n, df in enumerate(frames2_expand00):
    
    ax[count1,count2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = df.plot(x=xval,y=yval, alpha=1, c=colorse[0], linewidth=0.5,  ax=ax[count1,count2], ylim=[-1350,-1100])
    
    df1 = df[df['count_interaction_constraint'] <= 1]
    axname = df1.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[1], s=10, ax=ax[count1,count2])
    
    df2 = df[df['count_constraint']<=6]
    axname = df2.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[2], marker='x',s=100, ax=ax[count1,count2])

    if n == run:
        axname = best3d.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[3],marker='x', s=100, ax=ax[count1,count2])
        
    count1,count2 = countingfunction1(count1,count2)
    
plt.show()
plt.savefig('02-expand00' + str(2) + '.png')
# Out:
# Best structure: CopStems_expand_long00_02_10_10-001469.ss_dete...
# Energy: -1225.814224
# Interactionlength: 6, StackingBPs: 6

# %%
print('SINGLE RUNS - 2 - EXPAND 10.000 steps')
print('start structure')
print('((((((((((((((((((((.((........)))))).)))))))))))))))) (((.(.(((((((.(((.((........))..)))))))))).).)))')
print('........................(((((......................... ......................))))).....................')
print()
print('constraint (7):')
print('((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))')
print('.......................(((((((........................ .....................)))))))....................')

fig, ax = plt.subplots(nrows=10, ncols=2,figsize=[100,80])
fig.subplots_adjust(hspace=0.8, wspace=0.4)

titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= ['interaction_countbp','len_interaction']
yval = str('energy_value')
fig.suptitle('EXPAND 10,000 RUN 3 --> 5 - single runs')

switch = 0
figpos1 = 0
figpos2 = 0

for n, df in enumerate(frames2_expand):
    #ax[figpos1,figpos2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)
    
    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
    #ax[figpos1,figpos2].set_title(titles[n])
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)

    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
plt.show()
plt.savefig('02-expand' + str(1) + '.png')
# Out:
# SINGLE RUNS - 2 - EXPAND 10.000 steps
# start structure
# ((((((((((((((((((((.((........)))))).)))))))))))))))) (((.(.(((((((.(((.((........))..)))))))))).).)))
# ........................(((((......................... ......................))))).....................
#
# constraint (7):
# ((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))
# .......................(((((((........................ .....................)))))))....................

# %%
#Extract the trafl-name and the list number from the .ss_detected name
best3d = (dfint2_expand_best.head(1))
name = best3d.iloc[:,0].to_string(index=False).strip()
print('Best structure: {}'.format(name))
print('Energy: {}'.format(best3d.iloc[0]['energy_value']))
print('Interactionlength: {}, StackingBPs: {}'.format(best3d.iloc[0]['len_interaction'],best3d.iloc[0]['interaction_countbp']))
run = int(name.split('.')[0].split('_')[3])-1 #iterate dfs starts with 0

plt.rcParams['figure.figsize'] = [15, 5]
fig, ax = plt.subplots(nrows=5, ncols=2,figsize=[80,60])
fig.subplots_adjust(hspace=0.5, wspace=0.2)
titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= str('time')
yval = str('energy_value')
fig.suptitle('EXPAND 10,000 RUN 3 --> 5 - single runs, interaction_constraint=0, count constraint<=6')

count1, count2 = 0,0

for n, df in enumerate(frames2_expand):
    
    ax[count1,count2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = df.plot(x=xval,y=yval, alpha=1, c=colorse[0], linewidth=0.5,  ax=ax[count1,count2], ylim=[-1350,-1100])
    
    df1 = df[df['count_interaction_constraint'] <= 1]
    axname = df1.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[1], s=10, ax=ax[count1,count2])
    
    df2 = df[df['count_constraint']<=6]
    axname = df2.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[2], marker='x',s=100, ax=ax[count1,count2])

    if n == run:
        axname = best3d.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[3],marker='x', s=100, ax=ax[count1,count2])
        
    count1,count2 = countingfunction1(count1,count2)
    
plt.show()
plt.savefig('02-expand' + str(2) + '.png')
# Out:
# Best structure: CopStems_expand_02_10_10-007451.ss_detected
# Energy: -1210.6443
# Interactionlength: 6, StackingBPs: 6

# %%
print('SINGLE RUNS - 2 - EXPAND surface from 10,000 steps')
print('start structure')
print('((((((((((((((((((((.((........)))))).)))))))))))))))) (((.(.(((((((.(((.((........))..)))))))))).).)))')
print('........................(((((......................... ......................))))).....................')
print()
print('constraint (7):')
print('((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))')
print('.......................(((((((........................ .....................)))))))....................')

fig, ax = plt.subplots(nrows=10, ncols=2,figsize=[100,80])
fig.subplots_adjust(hspace=0.8, wspace=0.4)

titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= ['interaction_countbp','len_interaction']
yval = str('energy_value')
fig.suptitle('EXPANDSURFACE 10,000 3 --> 5 - single runs')

plt.savefig('02-expandsurface' + str(1) + '.png')

switch = 0
figpos1 = 0
figpos2 = 0

for n, df in enumerate(frames2_expandsurface):
    #ax[figpos1,figpos2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)
    
    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
    #ax[figpos1,figpos2].set_title(titles[n])
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)

    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
plt.show()
# Out:
# SINGLE RUNS - 2 - EXPAND surface from 10,000 steps
# start structure
# ((((((((((((((((((((.((........)))))).)))))))))))))))) (((.(.(((((((.(((.((........))..)))))))))).).)))
# ........................(((((......................... ......................))))).....................
#
# constraint (7):
# ((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))
# .......................(((((((........................ .....................)))))))....................

# %%
#Extract the trafl-name and the list number from the .ss_detected name
best3d = (dfint2_expandsurface_best.head(1))
name = best3d.iloc[:,0].to_string(index=False).strip()
print('Best structure: {}'.format(name))
print('Energy: {}'.format(best3d.iloc[0]['energy_value']))
print('Interactionlength: {}, StackingBPs: {}'.format(best3d.iloc[0]['len_interaction'],best3d.iloc[0]['interaction_countbp']))
run = int(name.split('.')[0].split('_')[3])-1 #iterate dfs starts with 0

plt.rcParams['figure.figsize'] = [15, 5]
fig, ax = plt.subplots(nrows=5, ncols=2,figsize=[80,60])
fig.subplots_adjust(hspace=0.5, wspace=0.2)
titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= str('time')
yval = str('energy_value')
fig.suptitle('EXPANDSURFACE 10,000 RUN 3 --> 5 - single runs, interaction_constraint=0, count constraint<=5')

count1, count2 = 0,0

for n, df in enumerate(frames2_expandsurface):
    
    ax[count1,count2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = df.plot(x=xval,y=yval, alpha=1, c=colorse[0], linewidth=0.5,  ax=ax[count1,count2], ylim=[-1350,-1100])
    
    df1 = df[df['count_interaction_constraint'] <= 1]
    axname = df1.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[1], s=10, ax=ax[count1,count2])
    
    df2 = df[df['count_constraint']<=5]
    axname = df2.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[2], marker='x',s=100, ax=ax[count1,count2])

    if n == run:
        axname = best3d.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[3],marker='x', s=100, ax=ax[count1,count2])
        
    count1,count2 = countingfunction1(count1,count2)
    
plt.show()
plt.savefig('02-expandsurface' + str(2) + '.png')
# Out:
# Best structure: CopStems_expand_surface_02_10_10-004221.ss_det...
# Energy: -1263.3907390000004
# Interactionlength: 6, StackingBPs: 6

# %%
print('start structure')
print('((((((((((((((((((((.((........)))))).)))))))))))))))) (((.(.(((((((.(((.((........))..)))))))))).).)))')
print('........................(((((......................... ......................))))).....................')
print()
print('constraint (7):')
print('((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))')
print('.......................(((((((........................ .....................)))))))....................')

fig, ax = plt.subplots(nrows=6, ncols=2,figsize=[20,15])
fig.subplots_adjust(hspace=0.8, wspace=0.4)

titles=['5,000 steps','10,000 steps','surface']
xval= ['interaction_countbp','len_interaction']
yval = ['energy_value','energy_values_plus_restraint_score']
fig.suptitle('EXPAND 3 --> 5 - Summary')

plt.savefig('02-expand' + str(2) + '.png')
for i in range(6):
    for j in range(2):
        if i == 0 or i == 1:
            ax[i,j].set_title(titles[0])
        elif i == 2 or i == 3:
            ax[i,j].set_title(titles[1])
        else:
            ax[i,j].set_title(titles[2])

ax1 = sns.violinplot(x=xval[0],y=yval[0], data=df2_expand00, color=colorsv[0], ax=ax[0,0], bw=0.1)
ax2 = sns.violinplot(x=xval[0],y=yval[1], data=df2_expand00, color=colorsv[2], ax=ax[1,0], bw=0.1)
ax3 = sns.violinplot(x=xval[1],y=yval[0], data=df2_expand00, color=colorsv[1], ax=ax[0,1])
ax4 = sns.violinplot(x=xval[1],y=yval[1], data=df2_expand00, color=colorsv[3], ax=ax[1,1])

ax5 = sns.violinplot(x=xval[0],y=yval[0], data=df2_expand, color=colorsv[0], ax=ax[2,0], bw=0.1)
ax6 = sns.violinplot(x=xval[0],y=yval[1], data=df2_expand, color=colorsv[2], ax=ax[3,0], bw=0.1)
ax7 = sns.violinplot(x=xval[1],y=yval[0], data=df2_expand, color=colorsv[1], ax=ax[2,1])
ax8 = sns.violinplot(x=xval[1],y=yval[1], data=df2_expand, color=colorsv[3], ax=ax[3,1])

ax9 = sns.violinplot(x=xval[0],y=yval[0], data=df2_expandsurface, color=colorsv[0], ax=ax[4,0], bw=0.1)
ax10 = sns.violinplot(x=xval[0],y=yval[1], data=df2_expandsurface, color=colorsv[2], ax=ax[5,0], bw=0.1)
ax11 = sns.violinplot(x=xval[1],y=yval[0], data=df2_expandsurface, color=colorsv[1], ax=ax[4,1])
ax12 = sns.violinplot(x=xval[1],y=yval[1], data=df2_expandsurface, color=colorsv[3], ax=ax[5,1])

plt.show()
plt.savefig('02-expandsummary' + str(3) + '.png')
# Out:
# start structure
# ((((((((((((((((((((.((........)))))).)))))))))))))))) (((.(.(((((((.(((.((........))..)))))))))).).)))
# ........................(((((......................... ......................))))).....................
#
# constraint (7):
# ((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))
# .......................(((((((........................ .....................)))))))....................

# %%
titles=['5,000 steps','10,000 steps','surface']

for nr, plot in enumerate(titles):
    if nr == 0:
        fig.suptitle('EXPAND 5,000 RUN 3 --> 5')
        name =str('02-expand00' + str(4) + '.png')
        ax = dfbp2_expand00.plot.hexbin(x='bp1',y='bp2', C='count', alpha=1,  gridsize=70, cmap="viridis",title=titles[nr])

    if nr == 1:
        fig.suptitle('EXPAND 10,000 RUN 3 --> 5')
        name =str('02-expand' + str(4) + '.png')
        ax = dfbp2_expand.plot.hexbin(x='bp1',y='bp2', C='count', alpha=1,  gridsize=70, cmap="viridis",title=titles[nr])

    if nr == 2:
        fig.suptitle('EXPANDSURFACE 5,000 RUN 3 --> 5')
        name =str('02-expandsurface' + str(4) + '.png')
        ax = dfbp2_expandsurface.plot.hexbin(x='bp1',y='bp2', C='count', alpha=1,  gridsize=70, cmap="viridis",title=titles[nr])

    xticklabels = slist
    ax.set_xticks(np.arange(len(slist)))
    ax.set_xticklabels(xticklabels)

    yticklabels = slist
    ax.set_yticks(np.arange(len(slist)))
    ax.set_yticklabels(xticklabels)

    ax.grid(axis='both',color='grey',linestyle='-', linewidth=0.5, alpha=0.2)
    ax.tick_params(axis='both', which='both', labelleft='on', labelright='on',labelbottom='on',labeltop='on')


    ax.set_aspect("equal")
    ax.axvline(x=chainbreak)
    ax.axhline(y=chainbreak)
    
    plt.show()
    plt.savefig(name)

# %%
print('SINGLE RUNS - 3 - EXPAND 5.000 steps')
print('start structure')
print('((((((((((((((((((((..((......)).)))).)))))))))))))))) (((.(.(((((((.(((.(..........)..)))))))))).).)))')
print('........................((((((........................ .....................)))))).....................')
print()
print('constraint (9):')
print('((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))')
print('......................(((((((((....................... ....................)))))))))...................')

fig, ax = plt.subplots(nrows=10, ncols=2,figsize=[100,80])
fig.subplots_adjust(hspace=0.8, wspace=0.4)

titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= ['interaction_countbp','len_interaction']
yval = str('energy_value')
fig.suptitle('EXPAND00 5,000 RUN 6 --> 9 - single runs')

switch = 0
figpos1 = 0
figpos2 = 0

for n, df in enumerate(frames3_expand00):
    #ax[figpos1,figpos2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)
    
    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
    #ax[figpos1,figpos2].set_title(titles[n])
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)

    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
plt.show()
plt.savefig('03-expand00' + str(1) + '.png')
# Out:
# SINGLE RUNS - 3 - EXPAND 5.000 steps
# start structure
# ((((((((((((((((((((..((......)).)))).)))))))))))))))) (((.(.(((((((.(((.(..........)..)))))))))).).)))
# ........................((((((........................ .....................)))))).....................
#
# constraint (9):
# ((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))
# ......................(((((((((....................... ....................)))))))))...................

# %%
#Extract the trafl-name and the list number from the .ss_detected name
best3d = (dfint3_expand00_best.head(1))
name = best3d.iloc[:,0].to_string(index=False).strip()
print('Best structure: {}'.format(name))
print('Energy: {}'.format(best3d.iloc[0]['energy_value']))
print('Interactionlength: {}, StackingBPs: {}'.format(best3d.iloc[0]['len_interaction'],best3d.iloc[0]['interaction_countbp']))
run = int(name.split('.')[0].split('_')[3])-1 #iterate dfs starts with 0

plt.rcParams['figure.figsize'] = [15, 5]
fig, ax = plt.subplots(nrows=5, ncols=2,figsize=[80,60])
fig.subplots_adjust(hspace=0.5, wspace=0.2)
titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= str('time')
yval = str('energy_value')
fig.suptitle('EXPAND 5,000 RUN 6 --> 9 - single runs, interaction_constraint<=3, count constraint<=7')

count1, count2 = 0,0

for n, df in enumerate(frames3_expand00):
    ax[count1,count2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = df.plot(x=xval,y=yval, alpha=1, c=colorse[0], linewidth=0.5,  ax=ax[count1,count2], ylim=[-1350,-1100])
    
    df1 = df[df['count_interaction_constraint'] <= 3]
    axname = df1.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[1], s=10, ax=ax[count1,count2])
    
    df2 = df[df['count_constraint']<=7]
    axname = df2.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[2], marker='x',s=100, ax=ax[count1,count2])

    if n == run:
        axname = best3d.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[3],marker='x', s=100, ax=ax[count1,count2])
        
    count1,count2 = countingfunction1(count1,count2)
    
plt.show()
plt.savefig('03-expand00' + str(2) + '.png')
# Out:
# Best structure: CopStems_expand_long00_03_10_10-001912.ss_dete...
# Energy: -1244.3365609999996
# Interactionlength: 6, StackingBPs: 6

# %%
print('SINGLE RUNS - 3 - EXPAND 10.000 steps')
print('start structure')
print('((((((((((((((((((((..((......)).)))).)))))))))))))))) (((.(.(((((((.(((.(..........)..)))))))))).).)))')
print('........................((((((........................ .....................)))))).....................')
print()
print('constraint (9):')
print('((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))')
print('......................(((((((((....................... ....................)))))))))...................')

fig, ax = plt.subplots(nrows=10, ncols=2,figsize=[100,80])
fig.subplots_adjust(hspace=0.8, wspace=0.4)

titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= ['interaction_countbp','len_interaction']
yval = str('energy_value')
fig.suptitle('EXPAND 10,000 RUN 6 --> 9 - single runs')

switch = 0
figpos1 = 0
figpos2 = 0

for n, df in enumerate(frames3_expand):
    #ax[figpos1,figpos2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)
    
    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
    #ax[figpos1,figpos2].set_title(titles[n])
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)

    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
plt.show()
plt.savefig('03-expand' + str(1) + '.png')
# Out:
# SINGLE RUNS - 3 - EXPAND 10.000 steps
# start structure
# ((((((((((((((((((((..((......)).)))).)))))))))))))))) (((.(.(((((((.(((.(..........)..)))))))))).).)))
# ........................((((((........................ .....................)))))).....................
#
# constraint (9):
# ((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))
# ......................(((((((((....................... ....................)))))))))...................

# %%
#Extract the trafl-name and the list number from the .ss_detected name
best3d = (dfint3_expand_best.head(1))
name = best3d.iloc[:,0].to_string(index=False).strip()
print('Best structure: {}'.format(name))
print('Energy: {}'.format(best3d.iloc[0]['energy_value']))
print('Interactionlength: {}, StackingBPs: {}'.format(best3d.iloc[0]['len_interaction'],best3d.iloc[0]['interaction_countbp']))
run = int(name.split('.')[0].split('_')[3])-1 #iterate dfs starts with 0

plt.rcParams['figure.figsize'] = [15, 5]
fig, ax = plt.subplots(nrows=5, ncols=2,figsize=[80,60])
fig.subplots_adjust(hspace=0.5, wspace=0.2)
titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= str('time')
yval = str('energy_value')
fig.suptitle('EXPAND 10,000 RUN 6 --> 9 - single runs, interaction_constraint<=3, count constraint<=7')

count1, count2 = 0,0

for n, df in enumerate(frames3_expand):
    ax[count1,count2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = df.plot(x=xval,y=yval, alpha=1, c=colorse[0], linewidth=0.5,  ax=ax[count1,count2], ylim=[-1350,-1100])
    
    df1 = df[df['count_interaction_constraint'] <= 3]
    axname = df1.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[1], s=10, ax=ax[count1,count2])
    
    df2 = df[df['count_constraint']<=7]
    axname = df2.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[2], marker='x',s=100, ax=ax[count1,count2])

    if n == run:
        axname = best3d.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[3],marker='x', s=100, ax=ax[count1,count2])
        
    count1,count2 = countingfunction1(count1,count2)
    
plt.show()
plt.savefig('03-expand' + str(2) + '.png')
# Out:
# Best structure: CopStems_expand_03_3_3-002773.ss_detected
# Energy: -1232.709064
# Interactionlength: 6, StackingBPs: 6

# %%
print('SINGLE RUNS - 3 - EXPAND Surface 10.000 steps')
print('start structure')
print('((((((((((((((((((((..((......)).)))).)))))))))))))))) (((.(.(((((((.(((.(..........)..)))))))))).).)))')
print('........................((((((........................ .....................)))))).....................')
print()
print('constraint (9):')
print('((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))')
print('......................(((((((((....................... ....................)))))))))...................')

fig, ax = plt.subplots(nrows=10, ncols=2,figsize=[100,80])
fig.subplots_adjust(hspace=0.8, wspace=0.4)

titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= ['interaction_countbp','len_interaction']
yval = str('energy_value')
fig.suptitle('EXPANDSURFACE 10,000 RUN 6 --> 9 - single runs')

switch = 0
figpos1 = 0
figpos2 = 0

for n, df in enumerate(frames3_expandsurface):
    #ax[figpos1,figpos2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)
    
    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
    #ax[figpos1,figpos2].set_title(titles[n])
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)

    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
plt.show()
plt.savefig('03-expandsurface' + str(1) + '.png')
# Out:
# SINGLE RUNS - 3 - EXPAND Surface 10.000 steps
# start structure
# ((((((((((((((((((((..((......)).)))).)))))))))))))))) (((.(.(((((((.(((.(..........)..)))))))))).).)))
# ........................((((((........................ .....................)))))).....................
#
# constraint (9):
# ((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))
# ......................(((((((((....................... ....................)))))))))...................

# %%
#Extract the trafl-name and the list number from the .ss_detected name
best3d = (dfint3_expandsurface_best.head(1))
name = best3d.iloc[:,0].to_string(index=False).strip()
print('Best structure: {}'.format(name))
print('Energy: {}'.format(best3d.iloc[0]['energy_value']))
print('Interactionlength: {}, StackingBPs: {}'.format(best3d.iloc[0]['len_interaction'],best3d.iloc[0]['interaction_countbp']))
run = int(name.split('.')[0].split('_')[3])-1 #iterate dfs starts with 0

plt.rcParams['figure.figsize'] = [15, 5]
fig, ax = plt.subplots(nrows=5, ncols=2,figsize=[80,60])
fig.subplots_adjust(hspace=0.5, wspace=0.2)
titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= str('time')
yval = str('energy_value')
fig.suptitle('EXPANDSURFACE 10,000 RUN 6 --> 9 - single runs, interaction_constraint<=3, count constraint<=7')

count1, count2 = 0,0

for n, df in enumerate(frames3_expandsurface):
    ax[count1,count2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = df.plot(x=xval,y=yval, alpha=1, c=colorse[0], linewidth=0.5,  ax=ax[count1,count2], ylim=[-1350,-1100])
    
    df1 = df[df['count_interaction_constraint'] <= 3]
    axname = df1.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[1], s=10, ax=ax[count1,count2])
    
    df2 = df[df['count_constraint']<=7]
    axname = df2.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[2], marker='x',s=100, ax=ax[count1,count2])

    if n == run:
        axname = best3d.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[3],marker='x', s=100, ax=ax[count1,count2])
        
    count1,count2 = countingfunction1(count1,count2)
    
plt.show()
plt.savefig('03-expandsurface' + str(2) + '.png')
# Out:
# Best structure: CopStems_expand_surface_03_4_4-000002.ss_detected
# Energy: -1260.155165
# Interactionlength: 6, StackingBPs: 6

# %%
print('start structure')
print('((((((((((((((((((((..((......)).)))).)))))))))))))))) (((.(.(((((((.(((.(..........)..)))))))))).).)))')
print('........................((((((........................ .....................)))))).....................')
print()
print('constraint (9):')
print('((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))')
print('......................(((((((((....................... ....................)))))))))...................')


fig, ax = plt.subplots(nrows=6, ncols=2,figsize=[20,15])
fig.subplots_adjust(hspace=0.8, wspace=0.4)
fig.suptitle('Expand 5 --> 7bp')

titles=['5,000 steps','10,000 steps','surface']
xval= ['interaction_countbp','len_interaction']
yval = ['energy_value','energy_values_plus_restraint_score']
fig.suptitle('EXPAND Summary 6 --> 9')

for i in range(6):
    for j in range(2):
        if i == 0 or i == 1:
            ax[i,j].set_title(titles[0])
        elif i == 2 or i == 3:
            ax[i,j].set_title(titles[1])
        else:
            ax[i,j].set_title(titles[2])

ax1 = sns.violinplot(x=xval[0],y=yval[0], data=df3_expand00, color=colorsv[0], ax=ax[0,0],bw=0.1)
ax2 = sns.violinplot(x=xval[0],y=yval[1], data=df3_expand00, color=colorsv[2], ax=ax[1,0],bw=0.1)
ax3 = sns.violinplot(x=xval[1],y=yval[0], data=df3_expand00, color=colorsv[1], ax=ax[0,1],bw=0.1)
ax4 = sns.violinplot(x=xval[1],y=yval[1], data=df3_expand00, color=colorsv[3], ax=ax[1,1],bw=0.1)

ax5 = sns.violinplot(x=xval[0],y=yval[0], data=df3_expand, color=colorsv[0], ax=ax[2,0],bw=0.1)
ax6 = sns.violinplot(x=xval[0],y=yval[1], data=df3_expand, color=colorsv[2], ax=ax[3,0],bw=0.1)
ax7 = sns.violinplot(x=xval[1],y=yval[0], data=df3_expand, color=colorsv[1], ax=ax[2,1],bw=0.1)
ax8 = sns.violinplot(x=xval[1],y=yval[1], data=df3_expand, color=colorsv[3], ax=ax[3,1],bw=0.1)

ax9 = sns.violinplot(x=xval[0],y=yval[0], data=df3_expandsurface, color=colorsv[0], ax=ax[4,0],bw=0.1)
ax10 = sns.violinplot(x=xval[0],y=yval[1], data=df3_expandsurface, color=colorsv[2], ax=ax[5,0],bw=0.1)
ax11 = sns.violinplot(x=xval[1],y=yval[0], data=df3_expandsurface, color=colorsv[1], ax=ax[4,1],bw=0.1)
ax12 = sns.violinplot(x=xval[1],y=yval[1], data=df3_expandsurface, color=colorsv[3], ax=ax[5,1],bw=0.1)

plt.show()
plt.savefig('03-expandssummary' + str(3) + '.png')
# Out:
# start structure
# ((((((((((((((((((((..((......)).)))).)))))))))))))))) (((.(.(((((((.(((.(..........)..)))))))))).).)))
# ........................((((((........................ .....................)))))).....................
#
# constraint (9):
# ((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))
# ......................(((((((((....................... ....................)))))))))...................

# %%
titles=['5,000 steps','10,000 steps','surface']

for nr, plot in enumerate(titles):
    if nr == 0:
        fig.suptitle('EXPAND 5,000 RUN 5 --> 7')
        name =str('03-expand00' + str(4) + '.png')
        ax = dfbp3_expand00.plot.hexbin(x='bp1',y='bp2', C='count', alpha=1,  gridsize=70, cmap="viridis",title=titles[nr])

    if nr == 1:
        fig.suptitle('EXPAND 10,000 RUN 5 --> 7')
        name =str('03-expand' + str(4) + '.png')
        ax = dfbp3_expand.plot.hexbin(x='bp1',y='bp2', C='count', alpha=1,  gridsize=70, cmap="viridis",title=titles[nr])

    if nr == 2:
        fig.suptitle('EXPANDSURFACE 5,000 RUN 5 --> 7')
        name =str('03-expandsurface' + str(4) + '.png')
        ax = dfbp3_expandsurface.plot.hexbin(x='bp1',y='bp2', C='count', alpha=1,  gridsize=70, cmap="viridis",title=titles[nr])

    xticklabels = slist
    ax.set_xticks(np.arange(len(slist)))
    ax.set_xticklabels(xticklabels)

    yticklabels = slist
    ax.set_yticks(np.arange(len(slist)))
    ax.set_yticklabels(xticklabels)

    ax.grid(axis='both',color='grey',linestyle='-', linewidth=0.5, alpha=0.2)
    ax.tick_params(axis='both', which='both', labelleft='on', labelright='on',labelbottom='on',labeltop='on')


    ax.set_aspect("equal")
    ax.axvline(x=chainbreak)
    ax.axhline(y=chainbreak)
    
    plt.show()
    plt.savefig(name)

# %%
print('SINGLE RUNS - 3 - EXPAND HEAVY')
print('start structure')
print('((((((((((((((((((((..((......)).)))).)))))))))))))))) (((.(.(((((((.(((.(..........)..)))))))))).).)))')
print('........................((((((........................ .....................)))))).....................')
print()
print('constraint (9):')
print('((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))')
print('......................(((((((((....................... ....................)))))))))...................')
print()

fig, ax = plt.subplots(nrows=10, ncols=2,figsize=[100,80])
fig.subplots_adjust(hspace=0.8, wspace=0.4)

titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= ['interaction_countbp','len_interaction']
yval = str('energy_value')
fig.suptitle('EXPAND HEAVY 6 --> 9 - single runs')

switch = 0
figpos1 = 0
figpos2 = 0

for n, df in enumerate(frames3_expandheavy):
    #ax[figpos1,figpos2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)
    
    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
    #ax[figpos1,figpos2].set_title(titles[n])
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)

    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
plt.show()
plt.savefig('03-expandheavy' + str(1) + '.png')
# Out:
# SINGLE RUNS - 3 - EXPAND HEAVY
# start structure
# ((((((((((((((((((((..((......)).)))).)))))))))))))))) (((.(.(((((((.(((.(..........)..)))))))))).).)))
# ........................((((((........................ .....................)))))).....................
#
# constraint (9):
# ((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))
# ......................(((((((((....................... ....................)))))))))...................

# %%
#Extract the trafl-name and the list number from the .ss_detected name
best3d = (dfint3_expandheavy_best.head(1))
name = best3d.iloc[:,0].to_string(index=False).strip()
print('Best structure: {}'.format(name))
print('Energy: {}'.format(best3d.iloc[0]['energy_value']))
print('Interactionlength: {}, StackingBPs: {}'.format(best3d.iloc[0]['len_interaction'],best3d.iloc[0]['interaction_countbp']))
run = int(name.split('.')[0].split('_')[3])-1 #iterate dfs starts with 0

plt.rcParams['figure.figsize'] = [15, 5]
fig, ax = plt.subplots(nrows=5, ncols=2,figsize=[80,60])
fig.subplots_adjust(hspace=0.5, wspace=0.2)
titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= str('time')
yval = str('energy_value')
fig.suptitle('EXPAND HEAVY 6 --> 9 - single runs, interaction_constraint<=1, count constraint<=2')


count1, count2 = 0,0

for n, df in enumerate(frames3_expandheavy):
    ax[count1,count2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = df.plot(x=xval,y=yval, alpha=1, c=colorse[0], linewidth=0.5,  ax=ax[count1,count2], ylim=[-1300,-800])
    
    df1 = df[df['count_interaction_constraint'] <= 1]
    axname = df1.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[1], s=10, ax=ax[count1,count2])
    
    df2 = df[df['count_constraint']<=2]
    axname = df2.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[2], marker='x',s=100, ax=ax[count1,count2])

    if n == run:
        axname = best3d.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[3],marker='x', s=100, ax=ax[count1,count2])
        
    count1,count2 = countingfunction1(count1,count2)
    
plt.show()
plt.savefig('03-expandheavy' + str(2) + '.png')
# Out:
# Best structure: CopStemsHeavy_expand_03_5_5-005240.ss_detected
# Energy: -1222.526081
# Interactionlength: 7, StackingBPs: 8

# %%
print('SURFACE FROM AN 8-bp STRUCTURE 10.000 steps')
print('start --> surface:')
print('((((((((((((((((((((..(........).)))).)))))))))))))))) (((.(.(((((((.(((...............)))))))))).).)))')
print('.......................((((((((....................... ....................))))))))....................')

fig, ax = plt.subplots(nrows=10, ncols=2,figsize=[100,80])
fig.subplots_adjust(hspace=0.8, wspace=0.4)

titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= ['interaction_countbp','len_interaction']
yval = str('energy_value')
fig.suptitle('8BP - single runs,')

switch = 0
figpos1 = 0
figpos2 = 0

for n, df in enumerate(frames_8bp):
    #ax[figpos1,figpos2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)
    
    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
    #ax[figpos1,figpos2].set_title(titles[n])
    axname = sns.violinplot(x=xval[switch],y=yval, data=df , color=colorsv[switch], ax=ax[figpos1,figpos2], bw=0.1)

    figpos1, figpos2, switch = numbers(figpos1, figpos2, switch)
    
plt.show()
plt.savefig('8bp' + str(2) + '.png')
# Out:
# SURFACE FROM AN 8-bp STRUCTURE 10.000 steps
# start --> surface:
# ((((((((((((((((((((..(........).)))).)))))))))))))))) (((.(.(((((((.(((...............)))))))))).).)))
# .......................((((((((....................... ....................))))))))....................

# %%
#Extract the trafl-name and the list number from the .ss_detected name
best3d = (dfint_8bp_best.head(1))
name = best3d.iloc[:,0].to_string(index=False).strip()
print('Best structure: {}'.format(name))
print('Energy: {}'.format(best3d.iloc[0]['energy_value']))
print('Interactionlength: {}, StackingBPs: {}'.format(best3d.iloc[0]['len_interaction'],best3d.iloc[0]['interaction_countbp']))
run = int(name.split('.')[0].split('_')[3])-1 #iterate dfs starts with 0

plt.rcParams['figure.figsize'] = [15, 5]
fig, ax = plt.subplots(nrows=5, ncols=2,figsize=[80,60])
fig.subplots_adjust(hspace=0.5, wspace=0.2)
titles=['run 1','run 2','run 3','run 4','run 5','run 6','run 7','run 8','run 9','run 10']
xval= str('time')
yval = str('energy_value')
fig.suptitle('8BP- single runs, interaction_constraint<=0, count constraint<=0')

count1, count2 = 0,0

for n, df in enumerate(frames_8bp):
    ax[count1,count2].set_title(titles[n])
    
    axname = str('ax'+str(n+1))
    axname = df.plot(x=xval,y=yval, alpha=1, c=colorse[0], linewidth=0.5,  ax=ax[count1,count2], ylim=[-1300,-800])
    
    df1 = df[df['count_interaction_constraint'] <= 0]
    axname = df1.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[1], s=10, ax=ax[count1,count2])
    
    df2 = df[df['count_constraint']<=0]
    axname = df2.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[2], marker='x',s=100, ax=ax[count1,count2])

    if n == run:
        axname = best3d.plot.scatter(x=xval,y=yval, alpha=1, c=colorse[3],marker='x', s=100, ax=ax[count1,count2])
        
    count1,count2 = countingfunction1(count1,count2)
    
plt.show()
plt.savefig('8bp' + str(2) + '.png')
# Out:
# Best structure: CopStems8bp_surface_04_4_4-000008.ss_detected
# Energy: -1261.575073
# Interactionlength: 8, StackingBPs: 8

# %%
print('start structure')
print('((((((((((((((((((((..((......)).)))).)))))))))))))))) (((.(.(((((((.(((.(..........)..)))))))))).).)))')
print('........................((((((........................ .....................)))))).....................')
print()
print('constraint (9):')
print('((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))')
print('......................(((((((((....................... ....................)))))))))...................')
print()
print()
print('start --> surface:')
print('((((((((((((((((((((..(........).)))).)))))))))))))))) (((.(.(((((((.(((...............)))))))))).).)))')
print('.......................((((((((....................... ....................))))))))....................')

print()
fig, ax = plt.subplots(nrows=4, ncols=2,figsize=[20,15])
fig.subplots_adjust(hspace=0.5, wspace=0.2)

colors=['cornflowerblue','seagreen']

titles=['10,000 steps, secweight 10000', 'surface (10,000 steps from 8bp structure)']
xval= ['interaction_countbp','len_interaction']
yval = ['energy_value','energy_values_plus_restraint_score']
fig.suptitle('EXPANDHEAVY 10,000 RUN 6 --> 9 | 8BP SUMMARY')

for i in range(4):
    for j in range(2):
        if i == 0 or i == 1:
            ax[i,j].set_title(titles[0])
        elif i == 2 or i == 3:
            ax[i,j].set_title(titles[1])

ax1 = sns.violinplot(x=xval[0],y=yval[0], data=df3_expandheavy, color=colorsv[0], ax=ax[0,0],bw=0.1)
ax2 = sns.violinplot(x=xval[0],y=yval[1], data=df3_expandheavy, color=colorsv[2], ax=ax[1,0],bw=0.1)
ax3 = sns.violinplot(x=xval[1],y=yval[0], data=df3_expandheavy, color=colorsv[1], ax=ax[0,1],bw=0.1)
ax4 = sns.violinplot(x=xval[1],y=yval[1], data=df3_expandheavy, color=colorsv[3], ax=ax[1,1],bw=0.1)

ax5 = sns.violinplot(x=xval[0],y=yval[0], data=df_8bp, color=colorsv[0], ax=ax[2,0],bw=0.1)
ax6 = sns.violinplot(x=xval[0],y=yval[1], data=df_8bp, color=colorsv[2], ax=ax[3,0],bw=0.1)
ax7 = sns.violinplot(x=xval[1],y=yval[0], data=df_8bp, color=colorsv[1], ax=ax[2,1],bw=0.1)
ax8 = sns.violinplot(x=xval[1],y=yval[1], data=df_8bp, color=colorsv[3], ax=ax[3,1],bw=0.1)

plt.show()
plt.savefig('03_heavy-8bp' + str(3) + '.png')
# Out:
# start structure
# ((((((((((((((((((((..((......)).)))).)))))))))))))))) (((.(.(((((((.(((.(..........)..)))))))))).).)))
# ........................((((((........................ .....................)))))).....................
#
# constraint (9):
# ((((((((((((((((((((.............)))).)))))))))))))))) (((((.(((((((.(((...............)))))))))).)))))
# ......................(((((((((....................... ....................)))))))))...................
#
#
# start --> surface:
# ((((((((((((((((((((..(........).)))).)))))))))))))))) (((.(.(((((((.(((...............)))))))))).).)))
# .......................((((((((....................... ....................))))))))....................

# %%
titles=['HEAVY','8bp']

for nr, plot in enumerate(titles):
    if nr == 0:
        fig.suptitle('EXPAND HEAVY 10,000 RUN 5 --> 9')
        name =str('03-expandheavy' + str(4) + '.png')

        ax = dfbp3_expandheavy.plot.hexbin(x='bp1',y='bp2', C='count', alpha=1,  gridsize=70, cmap="viridis",title=titles[nr])

    if nr == 1:
        fig.suptitle('8BP 10,000 RUN')
        name =str('8bp' + str(4) + '.png')
        ax = dfbp_8pb.plot.hexbin(x='bp1',y='bp2', C='count', alpha=1,  gridsize=70, cmap="viridis",title=titles[nr])

    xticklabels = slist
    ax.set_xticks(np.arange(len(slist)))
    ax.set_xticklabels(xticklabels)

    yticklabels = slist
    ax.set_yticks(np.arange(len(slist)))
    ax.set_yticklabels(xticklabels)

    ax.grid(axis='both',color='grey',linestyle='-', linewidth=0.5, alpha=0.2)
    ax.tick_params(axis='both', which='both', labelleft='on', labelright='on',labelbottom='on',labeltop='on')


    ax.set_aspect("equal")
    ax.axvline(x=chainbreak)
    ax.axhline(y=chainbreak)
    
    plt.show()
    plt.savefig(name)
